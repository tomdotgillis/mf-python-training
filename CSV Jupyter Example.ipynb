# %% [markdown]
# # Loading a CSV File into a Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
perflog_df = pd.read_csv('mssql_3.5.1_perf_log.csv')

# %%
perflog_df
# Out:
#       ELAPSED                            END_TIME  \
# 0      863193  2019-01-03 23:13:18.8930000 +00:00
# 1      497613  2019-01-03 23:07:28.0280000 +00:00
# 2      694162  2019-01-03 23:10:59.5410000 +00:00
# 3      189452  2019-01-03 23:02:49.9550000 +00:00
# 4     2664626  2019-01-03 23:47:20.0790000 +00:00
# 5      700134  2019-01-03 23:14:42.6930000 +00:00
# 6     1899577  2019-01-03 23:39:20.0010000 +00:00
# 7          29  2019-01-03 23:11:10.4170000 +00:00
# 8         294  2019-01-03 23:11:10.8550000 +00:00
# 9           2  2019-01-03 23:11:10.8610000 +00:00
# 10         16  2019-01-03 23:11:10.8800000 +00:00
# 11         14  2019-01-03 23:11:10.8990000 +00:00
# 12         66  2019-01-03 23:11:10.9690000 +00:00
# 13         66  2019-01-03 23:11:11.0400000 +00:00
# 14         27  2019-01-03 23:11:11.0240000 +00:00
# 15         20  2019-01-03 23:11:11.0660000 +00:00
# 16         38  2019-01-03 23:11:11.1080000 +00:00
# 17         27  2019-01-03 23:11:11.1900000 +00:00
# 18         17  2019-01-03 23:11:11.2130000 +00:00
# 19        896  2019-01-03 23:11:12.1120000 +00:00
# 20         17  2019-01-03 23:11:12.1320000 +00:00
# 21         14  2019-01-03 23:11:12.1510000 +00:00
# 22          6  2019-01-03 23:11:12.1610000 +00:00
# 23         20  2019-01-03 23:11:12.1850000 +00:00
# 24         19  2019-01-03 23:11:12.2090000 +00:00
# 25          6  2019-01-03 23:11:12.2560000 +00:00
# 26         21  2019-01-03 23:11:12.2820000 +00:00
# 27         15  2019-01-03 23:11:12.3030000 +00:00
# 28          3  2019-01-03 23:11:12.3080000 +00:00
# 29    1319606  2019-01-03 23:35:24.9130000 +00:00
# ...       ...                                 ...
# 1188      225  2019-01-15 10:55:22.8960000 +00:00
# 1189     6845  2019-01-15 10:55:29.7430000 +00:00
# 1190       49  2019-01-15 10:55:29.7950000 +00:00
# 1191     4748  2019-01-15 10:55:34.5570000 +00:00
# 1192        8  2019-01-15 16:04:39.1140000 +00:00
# 1193       15  2019-01-15 16:04:39.1330000 +00:00
# 1194   (null)                              (null)
# 1195      562  2019-01-15 16:04:39.8210000 +00:00
# 1196       49  2019-01-15 16:04:39.3120000 +00:00
# 1197       36  2019-01-15 16:04:39.3050000 +00:00
# 1198      502  2019-01-15 16:04:39.8180000 +00:00
# 1199      182  2019-01-15 16:04:39.5010000 +00:00
# 1200       11  2019-01-15 16:04:39.4730000 +00:00
# 1201      302  2019-01-15 16:04:39.8070000 +00:00
# 1202      136  2019-01-15 16:04:39.8020000 +00:00
# 1203        4  2019-01-15 16:04:39.8150000 +00:00
# 1204       15  2019-01-15 16:04:39.8450000 +00:00
# 1205        2  2019-01-15 19:19:43.3480000 +00:00
# 1206        9  2019-01-15 19:19:43.3580000 +00:00
# 1207   (null)                              (null)
# 1208      314  2019-01-15 19:19:43.6970000 +00:00
# 1209      104  2019-01-15 19:19:43.4890000 +00:00
# 1210       99  2019-01-15 19:19:43.4860000 +00:00
# 1211      202  2019-01-15 19:19:43.6940000 +00:00
# 1212       14  2019-01-15 19:19:43.5080000 +00:00
# 1213        8  2019-01-15 19:19:43.5050000 +00:00
# 1214      176  2019-01-15 19:19:43.6870000 +00:00
# 1215      120  2019-01-15 19:19:43.6830000 +00:00
# 1216        2  2019-01-15 19:19:43.6920000 +00:00
# 1217       10  2019-01-15 19:19:43.7100000 +00:00
#
#                                                 MONITOR  \
# 0                                       DCS.collectData
# 1                                       DCS.collectData
# 2                                       DCS.collectData
# 3                                       DCS.collectData
# 4                        transformEntityType PERMISSION
# 5                                 transformToPermission
# 6                           transformEntityType ACCOUNT
# 7                       transformEntityType APPLICATION
# 8       post-transform DbPerfUtil.updateTableStatistics
# 9                     removeDuplicateEntity APPLICATION
# 10                          transformEntityType ACCOUNT
# 11      post-transform DbPerfUtil.updateTableStatistics
# 12                        removeDuplicateEntity ACCOUNT
# 13                       transformEntityType PERMISSION
# 14                                transformToPermission
# 15      post-transform DbPerfUtil.updateTableStatistics
# 16                     removeDuplicateEntity PERMISSION
# 17            transformEntityType PERMISSION_TO_HOLDERS
# 18      post-transform DbPerfUtil.updateTableStatistics
# 19          removeDuplicateEntity PERMISSION_TO_HOLDERS
# 20          transformEntityType PERMISSIONS_FROM_HOLDER
# 21      post-transform DbPerfUtil.updateTableStatistics
# 22        removeDuplicateEntity PERMISSIONS_FROM_HOLDER
# 23    transformEntityType PERMISSION_HIERARCHY_TO_CHILD
# 24      post-transform DbPerfUtil.updateTableStatistics
# 25    removeDuplicateEntity PERMISSION_HIERARCHY_TO_...
# 26    transformEntityType PERMISSION_HIERARCHY_TO_PA...
# 27      post-transform DbPerfUtil.updateTableStatistics
# 28    removeDuplicateEntity PERMISSION_HIERARCHY_TO_...
# 29                             transformEntityType USER
# ...                                                 ...
# 1188  StartReview (Everyone and the kitchen sink): S...
# 1189  StartReview (Everyone and the kitchen sink): G...
# 1190  StartReview (Everyone and the kitchen sink): C...
# 1191  StartReview (Everyone and the kitchen sink): U...
# 1192           synchronizeWithDataProductionTasks : 172
# 1193     validate autocuration upload process -id : 172
# 1194                            Upload Users - id : 172
# 1195                          execute Account curation
# 1196  execute Account curation .executeCuration.uplo...
# 1197                    uploadCuration: getAccounts(53)
# 1198  execute Account curation .executeCuration.publish
# 1199                              updateCuratedAccounts
# 1200                          query for merged accounts
# 1201                                  Build search tags
# 1202              Building search tag table for ACCOUNT
# 1203                        updating account custodians
# 1204  Completing state update for autocuration proce...
# 1205           synchronizeWithDataProductionTasks : 173
# 1206     validate autocuration upload process -id : 173
# 1207                            Upload Users - id : 173
# 1208                          execute Account curation
# 1209  execute Account curation .executeCuration.uplo...
# 1210                    uploadCuration: getAccounts(54)
# 1211  execute Account curation .executeCuration.publish
# 1212                              updateCuratedAccounts
# 1213                          query for merged accounts
# 1214                                  Build search tags
# 1215              Building search tag table for ACCOUNT
# 1216                        updating account custodians
# 1217  Completing state update for autocuration proce...
#
#                               START_TIME    ID  THREAD_ID   DP_ID  \
# 0     2019-01-03 22:58:55.7000000 +00:00     1        133       3
# 1     2019-01-03 22:59:10.4150000 +00:00     2        139       5
# 2     2019-01-03 22:59:25.3790000 +00:00     3        144       7
# 3     2019-01-03 22:59:40.5030000 +00:00     4        167       9
# 4     2019-01-03 23:02:55.4530000 +00:00     5        201       9
# 5     2019-01-03 23:03:02.5590000 +00:00     6        201       9
# 6     2019-01-03 23:07:40.4240000 +00:00     7        253       5
# 7     2019-01-03 23:11:10.3880000 +00:00     8        294       7
# 8     2019-01-03 23:11:10.5610000 +00:00     9        294  (null)
# 9     2019-01-03 23:11:10.8590000 +00:00    10        294       7
# 10    2019-01-03 23:11:10.8640000 +00:00    11        294       7
# 11    2019-01-03 23:11:10.8850000 +00:00    12        294  (null)
# 12    2019-01-03 23:11:10.9030000 +00:00    13        294       7
# 13    2019-01-03 23:11:10.9740000 +00:00    14        294       7
# 14    2019-01-03 23:11:10.9970000 +00:00    15        294       7
# 15    2019-01-03 23:11:11.0460000 +00:00    16        294  (null)
# 16    2019-01-03 23:11:11.0700000 +00:00    17        294       7
# 17    2019-01-03 23:11:11.1630000 +00:00    18        294       7
# 18    2019-01-03 23:11:11.1960000 +00:00    19        294  (null)
# 19    2019-01-03 23:11:11.2160000 +00:00    20        294       7
# 20    2019-01-03 23:11:12.1150000 +00:00    21        294       7
# 21    2019-01-03 23:11:12.1370000 +00:00    22        294  (null)
# 22    2019-01-03 23:11:12.1550000 +00:00    23        294       7
# 23    2019-01-03 23:11:12.1650000 +00:00    24        294       7
# 24    2019-01-03 23:11:12.1900000 +00:00    25        294  (null)
# 25    2019-01-03 23:11:12.2500000 +00:00    26        294       7
# 26    2019-01-03 23:11:12.2610000 +00:00    27        294       7
# 27    2019-01-03 23:11:12.2880000 +00:00    28        294  (null)
# 28    2019-01-03 23:11:12.3050000 +00:00    29        294       7
# 29    2019-01-03 23:13:25.3070000 +00:00    30        294       3
# ...                                  ...   ...        ...     ...
# 1188  2019-01-15 10:55:22.6710000 +00:00  1189      18091  (null)
# 1189  2019-01-15 10:55:22.8980000 +00:00  1190      18091  (null)
# 1190  2019-01-15 10:55:29.7460000 +00:00  1191      18091  (null)
# 1191  2019-01-15 10:55:29.8090000 +00:00  1192      18091  (null)
# 1192  2019-01-15 16:04:39.1060000 +00:00  1193       3799     172
# 1193  2019-01-15 16:04:39.1180000 +00:00  1194       3799     172
# 1194  2019-01-15 16:04:39.1390000 +00:00  1195       3799     172
# 1195  2019-01-15 16:04:39.2590000 +00:00  1196       3799     172
# 1196  2019-01-15 16:04:39.2630000 +00:00  1197       3799     172
# 1197  2019-01-15 16:04:39.2690000 +00:00  1198       3799     172
# 1198  2019-01-15 16:04:39.3160000 +00:00  1199       3799     172
# 1199  2019-01-15 16:04:39.3190000 +00:00  1200       3799     172
# 1200  2019-01-15 16:04:39.4620000 +00:00  1201       3799     172
# 1201  2019-01-15 16:04:39.5050000 +00:00  1202       3799     172
# 1202  2019-01-15 16:04:39.6660000 +00:00  1203       3799  (null)
# 1203  2019-01-15 16:04:39.8110000 +00:00  1204       3799     172
# 1204  2019-01-15 16:04:39.8300000 +00:00  1205       3799     172
# 1205  2019-01-15 19:19:43.3460000 +00:00  1206        128     173
# 1206  2019-01-15 19:19:43.3490000 +00:00  1207        128     173
# 1207  2019-01-15 19:19:43.3610000 +00:00  1208        128     173
# 1208  2019-01-15 19:19:43.3830000 +00:00  1209        128     173
# 1209  2019-01-15 19:19:43.3850000 +00:00  1210        128     173
# 1210  2019-01-15 19:19:43.3870000 +00:00  1211        128     173
# 1211  2019-01-15 19:19:43.4920000 +00:00  1212        128     173
# 1212  2019-01-15 19:19:43.4940000 +00:00  1213        128     173
# 1213  2019-01-15 19:19:43.4970000 +00:00  1214        128     173
# 1214  2019-01-15 19:19:43.5110000 +00:00  1215        128     173
# 1215  2019-01-15 19:19:43.5630000 +00:00  1216        128  (null)
# 1216  2019-01-15 19:19:43.6900000 +00:00  1217        128     173
# 1217  2019-01-15 19:19:43.7000000 +00:00  1218        128     173
#
#      PARENT_LOG_ID  OPS_SEQUENCE
# 0           (null)             5
# 1           (null)             5
# 2           (null)             5
# 3           (null)             5
# 4           (null)             5
# 5                5             5
# 6           (null)             5
# 7           (null)             5
# 8           (null)             5
# 9           (null)             5
# 10          (null)             5
# 11          (null)             5
# 12          (null)             5
# 13          (null)             5
# 14              14             5
# 15          (null)             5
# 16          (null)             5
# 17          (null)             5
# 18          (null)             5
# 19          (null)             5
# 20          (null)             5
# 21          (null)             5
# 22          (null)             5
# 23          (null)             5
# 24          (null)             5
# 25          (null)             5
# 26          (null)             5
# 27          (null)             5
# 28          (null)             5
# 29          (null)             5
# ...            ...           ...
# 1188        (null)             5
# 1189        (null)             5
# 1190        (null)             5
# 1191        (null)             5
# 1192        (null)             5
# 1193        (null)             5
# 1194        (null)             5
# 1195        (null)             5
# 1196          1196             5
# 1197        (null)             5
# 1198          1196             5
# 1199        (null)             5
# 1200        (null)             5
# 1201        (null)             5
# 1202        (null)             5
# 1203        (null)             5
# 1204        (null)             5
# 1205        (null)             5
# 1206        (null)             5
# 1207        (null)             5
# 1208        (null)             5
# 1209          1209             5
# 1210        (null)             5
# 1211          1209             5
# 1212        (null)             5
# 1213        (null)             5
# 1214        (null)             5
# 1215        (null)             5
# 1216        (null)             5
# 1217        (null)             5
#
# [1218 rows x 9 columns]

# %% [markdown]
# # Showing a column as a series

# %%
perflog_df.ELAPSED
# Out:
# 0        863193
# 1        497613
# 2        694162
# 3        189452
# 4       2664626
# 5        700134
# 6       1899577
# 7            29
# 8           294
# 9             2
# 10           16
# 11           14
# 12           66
# 13           66
# 14           27
# 15           20
# 16           38
# 17           27
# 18           17
# 19          896
# 20           17
# 21           14
# 22            6
# 23           20
# 24           19
# 25            6
# 26           21
# 27           15
# 28            3
# 29      1319606
#          ...
# 1188        225
# 1189       6845
# 1190         49
# 1191       4748
# 1192          8
# 1193         15
# 1194     (null)
# 1195        562
# 1196         49
# 1197         36
# 1198        502
# 1199        182
# 1200         11
# 1201        302
# 1202        136
# 1203          4
# 1204         15
# 1205          2
# 1206          9
# 1207     (null)
# 1208        314
# 1209        104
# 1210         99
# 1211        202
# 1212         14
# 1213          8
# 1214        176
# 1215        120
# 1216          2
# 1217         10
# Name: ELAPSED, Length: 1218, dtype: object

# %%
# Columns as a

# %%
perflog_df.dropna()
# Out:
#       ELAPSED                            END_TIME  \
# 0      863193  2019-01-03 23:13:18.8930000 +00:00
# 1      497613  2019-01-03 23:07:28.0280000 +00:00
# 2      694162  2019-01-03 23:10:59.5410000 +00:00
# 3      189452  2019-01-03 23:02:49.9550000 +00:00
# 4     2664626  2019-01-03 23:47:20.0790000 +00:00
# 5      700134  2019-01-03 23:14:42.6930000 +00:00
# 6     1899577  2019-01-03 23:39:20.0010000 +00:00
# 7          29  2019-01-03 23:11:10.4170000 +00:00
# 8         294  2019-01-03 23:11:10.8550000 +00:00
# 9           2  2019-01-03 23:11:10.8610000 +00:00
# 10         16  2019-01-03 23:11:10.8800000 +00:00
# 11         14  2019-01-03 23:11:10.8990000 +00:00
# 12         66  2019-01-03 23:11:10.9690000 +00:00
# 13         66  2019-01-03 23:11:11.0400000 +00:00
# 14         27  2019-01-03 23:11:11.0240000 +00:00
# 15         20  2019-01-03 23:11:11.0660000 +00:00
# 16         38  2019-01-03 23:11:11.1080000 +00:00
# 17         27  2019-01-03 23:11:11.1900000 +00:00
# 18         17  2019-01-03 23:11:11.2130000 +00:00
# 19        896  2019-01-03 23:11:12.1120000 +00:00
# 20         17  2019-01-03 23:11:12.1320000 +00:00
# 21         14  2019-01-03 23:11:12.1510000 +00:00
# 22          6  2019-01-03 23:11:12.1610000 +00:00
# 23         20  2019-01-03 23:11:12.1850000 +00:00
# 24         19  2019-01-03 23:11:12.2090000 +00:00
# 25          6  2019-01-03 23:11:12.2560000 +00:00
# 26         21  2019-01-03 23:11:12.2820000 +00:00
# 27         15  2019-01-03 23:11:12.3030000 +00:00
# 28          3  2019-01-03 23:11:12.3080000 +00:00
# 29    1319606  2019-01-03 23:35:24.9130000 +00:00
# ...       ...                                 ...
# 1188      225  2019-01-15 10:55:22.8960000 +00:00
# 1189     6845  2019-01-15 10:55:29.7430000 +00:00
# 1190       49  2019-01-15 10:55:29.7950000 +00:00
# 1191     4748  2019-01-15 10:55:34.5570000 +00:00
# 1192        8  2019-01-15 16:04:39.1140000 +00:00
# 1193       15  2019-01-15 16:04:39.1330000 +00:00
# 1194   (null)                              (null)
# 1195      562  2019-01-15 16:04:39.8210000 +00:00
# 1196       49  2019-01-15 16:04:39.3120000 +00:00
# 1197       36  2019-01-15 16:04:39.3050000 +00:00
# 1198      502  2019-01-15 16:04:39.8180000 +00:00
# 1199      182  2019-01-15 16:04:39.5010000 +00:00
# 1200       11  2019-01-15 16:04:39.4730000 +00:00
# 1201      302  2019-01-15 16:04:39.8070000 +00:00
# 1202      136  2019-01-15 16:04:39.8020000 +00:00
# 1203        4  2019-01-15 16:04:39.8150000 +00:00
# 1204       15  2019-01-15 16:04:39.8450000 +00:00
# 1205        2  2019-01-15 19:19:43.3480000 +00:00
# 1206        9  2019-01-15 19:19:43.3580000 +00:00
# 1207   (null)                              (null)
# 1208      314  2019-01-15 19:19:43.6970000 +00:00
# 1209      104  2019-01-15 19:19:43.4890000 +00:00
# 1210       99  2019-01-15 19:19:43.4860000 +00:00
# 1211      202  2019-01-15 19:19:43.6940000 +00:00
# 1212       14  2019-01-15 19:19:43.5080000 +00:00
# 1213        8  2019-01-15 19:19:43.5050000 +00:00
# 1214      176  2019-01-15 19:19:43.6870000 +00:00
# 1215      120  2019-01-15 19:19:43.6830000 +00:00
# 1216        2  2019-01-15 19:19:43.6920000 +00:00
# 1217       10  2019-01-15 19:19:43.7100000 +00:00
#
#                                                 MONITOR  \
# 0                                       DCS.collectData
# 1                                       DCS.collectData
# 2                                       DCS.collectData
# 3                                       DCS.collectData
# 4                        transformEntityType PERMISSION
# 5                                 transformToPermission
# 6                           transformEntityType ACCOUNT
# 7                       transformEntityType APPLICATION
# 8       post-transform DbPerfUtil.updateTableStatistics
# 9                     removeDuplicateEntity APPLICATION
# 10                          transformEntityType ACCOUNT
# 11      post-transform DbPerfUtil.updateTableStatistics
# 12                        removeDuplicateEntity ACCOUNT
# 13                       transformEntityType PERMISSION
# 14                                transformToPermission
# 15      post-transform DbPerfUtil.updateTableStatistics
# 16                     removeDuplicateEntity PERMISSION
# 17            transformEntityType PERMISSION_TO_HOLDERS
# 18      post-transform DbPerfUtil.updateTableStatistics
# 19          removeDuplicateEntity PERMISSION_TO_HOLDERS
# 20          transformEntityType PERMISSIONS_FROM_HOLDER
# 21      post-transform DbPerfUtil.updateTableStatistics
# 22        removeDuplicateEntity PERMISSIONS_FROM_HOLDER
# 23    transformEntityType PERMISSION_HIERARCHY_TO_CHILD
# 24      post-transform DbPerfUtil.updateTableStatistics
# 25    removeDuplicateEntity PERMISSION_HIERARCHY_TO_...
# 26    transformEntityType PERMISSION_HIERARCHY_TO_PA...
# 27      post-transform DbPerfUtil.updateTableStatistics
# 28    removeDuplicateEntity PERMISSION_HIERARCHY_TO_...
# 29                             transformEntityType USER
# ...                                                 ...
# 1188  StartReview (Everyone and the kitchen sink): S...
# 1189  StartReview (Everyone and the kitchen sink): G...
# 1190  StartReview (Everyone and the kitchen sink): C...
# 1191  StartReview (Everyone and the kitchen sink): U...
# 1192           synchronizeWithDataProductionTasks : 172
# 1193     validate autocuration upload process -id : 172
# 1194                            Upload Users - id : 172
# 1195                          execute Account curation
# 1196  execute Account curation .executeCuration.uplo...
# 1197                    uploadCuration: getAccounts(53)
# 1198  execute Account curation .executeCuration.publish
# 1199                              updateCuratedAccounts
# 1200                          query for merged accounts
# 1201                                  Build search tags
# 1202              Building search tag table for ACCOUNT
# 1203                        updating account custodians
# 1204  Completing state update for autocuration proce...
# 1205           synchronizeWithDataProductionTasks : 173
# 1206     validate autocuration upload process -id : 173
# 1207                            Upload Users - id : 173
# 1208                          execute Account curation
# 1209  execute Account curation .executeCuration.uplo...
# 1210                    uploadCuration: getAccounts(54)
# 1211  execute Account curation .executeCuration.publish
# 1212                              updateCuratedAccounts
# 1213                          query for merged accounts
# 1214                                  Build search tags
# 1215              Building search tag table for ACCOUNT
# 1216                        updating account custodians
# 1217  Completing state update for autocuration proce...
#
#                               START_TIME    ID  THREAD_ID   DP_ID  \
# 0     2019-01-03 22:58:55.7000000 +00:00     1        133       3
# 1     2019-01-03 22:59:10.4150000 +00:00     2        139       5
# 2     2019-01-03 22:59:25.3790000 +00:00     3        144       7
# 3     2019-01-03 22:59:40.5030000 +00:00     4        167       9
# 4     2019-01-03 23:02:55.4530000 +00:00     5        201       9
# 5     2019-01-03 23:03:02.5590000 +00:00     6        201       9
# 6     2019-01-03 23:07:40.4240000 +00:00     7        253       5
# 7     2019-01-03 23:11:10.3880000 +00:00     8        294       7
# 8     2019-01-03 23:11:10.5610000 +00:00     9        294  (null)
# 9     2019-01-03 23:11:10.8590000 +00:00    10        294       7
# 10    2019-01-03 23:11:10.8640000 +00:00    11        294       7
# 11    2019-01-03 23:11:10.8850000 +00:00    12        294  (null)
# 12    2019-01-03 23:11:10.9030000 +00:00    13        294       7
# 13    2019-01-03 23:11:10.9740000 +00:00    14        294       7
# 14    2019-01-03 23:11:10.9970000 +00:00    15        294       7
# 15    2019-01-03 23:11:11.0460000 +00:00    16        294  (null)
# 16    2019-01-03 23:11:11.0700000 +00:00    17        294       7
# 17    2019-01-03 23:11:11.1630000 +00:00    18        294       7
# 18    2019-01-03 23:11:11.1960000 +00:00    19        294  (null)
# 19    2019-01-03 23:11:11.2160000 +00:00    20        294       7
# 20    2019-01-03 23:11:12.1150000 +00:00    21        294       7
# 21    2019-01-03 23:11:12.1370000 +00:00    22        294  (null)
# 22    2019-01-03 23:11:12.1550000 +00:00    23        294       7
# 23    2019-01-03 23:11:12.1650000 +00:00    24        294       7
# 24    2019-01-03 23:11:12.1900000 +00:00    25        294  (null)
# 25    2019-01-03 23:11:12.2500000 +00:00    26        294       7
# 26    2019-01-03 23:11:12.2610000 +00:00    27        294       7
# 27    2019-01-03 23:11:12.2880000 +00:00    28        294  (null)
# 28    2019-01-03 23:11:12.3050000 +00:00    29        294       7
# 29    2019-01-03 23:13:25.3070000 +00:00    30        294       3
# ...                                  ...   ...        ...     ...
# 1188  2019-01-15 10:55:22.6710000 +00:00  1189      18091  (null)
# 1189  2019-01-15 10:55:22.8980000 +00:00  1190      18091  (null)
# 1190  2019-01-15 10:55:29.7460000 +00:00  1191      18091  (null)
# 1191  2019-01-15 10:55:29.8090000 +00:00  1192      18091  (null)
# 1192  2019-01-15 16:04:39.1060000 +00:00  1193       3799     172
# 1193  2019-01-15 16:04:39.1180000 +00:00  1194       3799     172
# 1194  2019-01-15 16:04:39.1390000 +00:00  1195       3799     172
# 1195  2019-01-15 16:04:39.2590000 +00:00  1196       3799     172
# 1196  2019-01-15 16:04:39.2630000 +00:00  1197       3799     172
# 1197  2019-01-15 16:04:39.2690000 +00:00  1198       3799     172
# 1198  2019-01-15 16:04:39.3160000 +00:00  1199       3799     172
# 1199  2019-01-15 16:04:39.3190000 +00:00  1200       3799     172
# 1200  2019-01-15 16:04:39.4620000 +00:00  1201       3799     172
# 1201  2019-01-15 16:04:39.5050000 +00:00  1202       3799     172
# 1202  2019-01-15 16:04:39.6660000 +00:00  1203       3799  (null)
# 1203  2019-01-15 16:04:39.8110000 +00:00  1204       3799     172
# 1204  2019-01-15 16:04:39.8300000 +00:00  1205       3799     172
# 1205  2019-01-15 19:19:43.3460000 +00:00  1206        128     173
# 1206  2019-01-15 19:19:43.3490000 +00:00  1207        128     173
# 1207  2019-01-15 19:19:43.3610000 +00:00  1208        128     173
# 1208  2019-01-15 19:19:43.3830000 +00:00  1209        128     173
# 1209  2019-01-15 19:19:43.3850000 +00:00  1210        128     173
# 1210  2019-01-15 19:19:43.3870000 +00:00  1211        128     173
# 1211  2019-01-15 19:19:43.4920000 +00:00  1212        128     173
# 1212  2019-01-15 19:19:43.4940000 +00:00  1213        128     173
# 1213  2019-01-15 19:19:43.4970000 +00:00  1214        128     173
# 1214  2019-01-15 19:19:43.5110000 +00:00  1215        128     173
# 1215  2019-01-15 19:19:43.5630000 +00:00  1216        128  (null)
# 1216  2019-01-15 19:19:43.6900000 +00:00  1217        128     173
# 1217  2019-01-15 19:19:43.7000000 +00:00  1218        128     173
#
#      PARENT_LOG_ID  OPS_SEQUENCE
# 0           (null)             5
# 1           (null)             5
# 2           (null)             5
# 3           (null)             5
# 4           (null)             5
# 5                5             5
# 6           (null)             5
# 7           (null)             5
# 8           (null)             5
# 9           (null)             5
# 10          (null)             5
# 11          (null)             5
# 12          (null)             5
# 13          (null)             5
# 14              14             5
# 15          (null)             5
# 16          (null)             5
# 17          (null)             5
# 18          (null)             5
# 19          (null)             5
# 20          (null)             5
# 21          (null)             5
# 22          (null)             5
# 23          (null)             5
# 24          (null)             5
# 25          (null)             5
# 26          (null)             5
# 27          (null)             5
# 28          (null)             5
# 29          (null)             5
# ...            ...           ...
# 1188        (null)             5
# 1189        (null)             5
# 1190        (null)             5
# 1191        (null)             5
# 1192        (null)             5
# 1193        (null)             5
# 1194        (null)             5
# 1195        (null)             5
# 1196          1196             5
# 1197        (null)             5
# 1198          1196             5
# 1199        (null)             5
# 1200        (null)             5
# 1201        (null)             5
# 1202        (null)             5
# 1203        (null)             5
# 1204        (null)             5
# 1205        (null)             5
# 1206        (null)             5
# 1207        (null)             5
# 1208        (null)             5
# 1209          1209             5
# 1210        (null)             5
# 1211          1209             5
# 1212        (null)             5
# 1213        (null)             5
# 1214        (null)             5
# 1215        (null)             5
# 1216        (null)             5
# 1217        (null)             5
#
# [1218 rows x 9 columns]

# %%
perflog_df.dtypes
# Out:
# ELAPSED          object
# END_TIME         object
# MONITOR          object
# START_TIME       object
# ID                int64
# THREAD_ID         int64
# DP_ID            object
# PARENT_LOG_ID    object
# OPS_SEQUENCE      int64
# dtype: object

# %%
perflog_df_no_nulls = perflog_df.query("ELAPSED != '(null)'")

# %%
perflog_df_no_nulls
# Out:
#        ELAPSED                            END_TIME  \
# 0       863193  2019-01-03 23:13:18.8930000 +00:00
# 1       497613  2019-01-03 23:07:28.0280000 +00:00
# 2       694162  2019-01-03 23:10:59.5410000 +00:00
# 3       189452  2019-01-03 23:02:49.9550000 +00:00
# 4      2664626  2019-01-03 23:47:20.0790000 +00:00
# 5       700134  2019-01-03 23:14:42.6930000 +00:00
# 6      1899577  2019-01-03 23:39:20.0010000 +00:00
# 7           29  2019-01-03 23:11:10.4170000 +00:00
# 8          294  2019-01-03 23:11:10.8550000 +00:00
# 9            2  2019-01-03 23:11:10.8610000 +00:00
# 10          16  2019-01-03 23:11:10.8800000 +00:00
# 11          14  2019-01-03 23:11:10.8990000 +00:00
# 12          66  2019-01-03 23:11:10.9690000 +00:00
# 13          66  2019-01-03 23:11:11.0400000 +00:00
# 14          27  2019-01-03 23:11:11.0240000 +00:00
# 15          20  2019-01-03 23:11:11.0660000 +00:00
# 16          38  2019-01-03 23:11:11.1080000 +00:00
# 17          27  2019-01-03 23:11:11.1900000 +00:00
# 18          17  2019-01-03 23:11:11.2130000 +00:00
# 19         896  2019-01-03 23:11:12.1120000 +00:00
# 20          17  2019-01-03 23:11:12.1320000 +00:00
# 21          14  2019-01-03 23:11:12.1510000 +00:00
# 22           6  2019-01-03 23:11:12.1610000 +00:00
# 23          20  2019-01-03 23:11:12.1850000 +00:00
# 24          19  2019-01-03 23:11:12.2090000 +00:00
# 25           6  2019-01-03 23:11:12.2560000 +00:00
# 26          21  2019-01-03 23:11:12.2820000 +00:00
# 27          15  2019-01-03 23:11:12.3030000 +00:00
# 28           3  2019-01-03 23:11:12.3080000 +00:00
# 29     1319606  2019-01-03 23:35:24.9130000 +00:00
# ...        ...                                 ...
# 1186         7  2019-01-05 10:37:25.2910000 +00:00
# 1187  43517206  2019-01-15 10:55:22.5000000 +00:00
# 1188       225  2019-01-15 10:55:22.8960000 +00:00
# 1189      6845  2019-01-15 10:55:29.7430000 +00:00
# 1190        49  2019-01-15 10:55:29.7950000 +00:00
# 1191      4748  2019-01-15 10:55:34.5570000 +00:00
# 1192         8  2019-01-15 16:04:39.1140000 +00:00
# 1193        15  2019-01-15 16:04:39.1330000 +00:00
# 1195       562  2019-01-15 16:04:39.8210000 +00:00
# 1196        49  2019-01-15 16:04:39.3120000 +00:00
# 1197        36  2019-01-15 16:04:39.3050000 +00:00
# 1198       502  2019-01-15 16:04:39.8180000 +00:00
# 1199       182  2019-01-15 16:04:39.5010000 +00:00
# 1200        11  2019-01-15 16:04:39.4730000 +00:00
# 1201       302  2019-01-15 16:04:39.8070000 +00:00
# 1202       136  2019-01-15 16:04:39.8020000 +00:00
# 1203         4  2019-01-15 16:04:39.8150000 +00:00
# 1204        15  2019-01-15 16:04:39.8450000 +00:00
# 1205         2  2019-01-15 19:19:43.3480000 +00:00
# 1206         9  2019-01-15 19:19:43.3580000 +00:00
# 1208       314  2019-01-15 19:19:43.6970000 +00:00
# 1209       104  2019-01-15 19:19:43.4890000 +00:00
# 1210        99  2019-01-15 19:19:43.4860000 +00:00
# 1211       202  2019-01-15 19:19:43.6940000 +00:00
# 1212        14  2019-01-15 19:19:43.5080000 +00:00
# 1213         8  2019-01-15 19:19:43.5050000 +00:00
# 1214       176  2019-01-15 19:19:43.6870000 +00:00
# 1215       120  2019-01-15 19:19:43.6830000 +00:00
# 1216         2  2019-01-15 19:19:43.6920000 +00:00
# 1217        10  2019-01-15 19:19:43.7100000 +00:00
#
#                                                 MONITOR  \
# 0                                       DCS.collectData
# 1                                       DCS.collectData
# 2                                       DCS.collectData
# 3                                       DCS.collectData
# 4                        transformEntityType PERMISSION
# 5                                 transformToPermission
# 6                           transformEntityType ACCOUNT
# 7                       transformEntityType APPLICATION
# 8       post-transform DbPerfUtil.updateTableStatistics
# 9                     removeDuplicateEntity APPLICATION
# 10                          transformEntityType ACCOUNT
# 11      post-transform DbPerfUtil.updateTableStatistics
# 12                        removeDuplicateEntity ACCOUNT
# 13                       transformEntityType PERMISSION
# 14                                transformToPermission
# 15      post-transform DbPerfUtil.updateTableStatistics
# 16                     removeDuplicateEntity PERMISSION
# 17            transformEntityType PERMISSION_TO_HOLDERS
# 18      post-transform DbPerfUtil.updateTableStatistics
# 19          removeDuplicateEntity PERMISSION_TO_HOLDERS
# 20          transformEntityType PERMISSIONS_FROM_HOLDER
# 21      post-transform DbPerfUtil.updateTableStatistics
# 22        removeDuplicateEntity PERMISSIONS_FROM_HOLDER
# 23    transformEntityType PERMISSION_HIERARCHY_TO_CHILD
# 24      post-transform DbPerfUtil.updateTableStatistics
# 25    removeDuplicateEntity PERMISSION_HIERARCHY_TO_...
# 26    transformEntityType PERMISSION_HIERARCHY_TO_PA...
# 27      post-transform DbPerfUtil.updateTableStatistics
# 28    removeDuplicateEntity PERMISSION_HIERARCHY_TO_...
# 29                             transformEntityType USER
# ...                                                 ...
# 1186                                    Detect ALL SoDs
# 1187  StartReview (Everyone and the kitchen sink): G...
# 1188  StartReview (Everyone and the kitchen sink): S...
# 1189  StartReview (Everyone and the kitchen sink): G...
# 1190  StartReview (Everyone and the kitchen sink): C...
# 1191  StartReview (Everyone and the kitchen sink): U...
# 1192           synchronizeWithDataProductionTasks : 172
# 1193     validate autocuration upload process -id : 172
# 1195                          execute Account curation
# 1196  execute Account curation .executeCuration.uplo...
# 1197                    uploadCuration: getAccounts(53)
# 1198  execute Account curation .executeCuration.publish
# 1199                              updateCuratedAccounts
# 1200                          query for merged accounts
# 1201                                  Build search tags
# 1202              Building search tag table for ACCOUNT
# 1203                        updating account custodians
# 1204  Completing state update for autocuration proce...
# 1205           synchronizeWithDataProductionTasks : 173
# 1206     validate autocuration upload process -id : 173
# 1208                          execute Account curation
# 1209  execute Account curation .executeCuration.uplo...
# 1210                    uploadCuration: getAccounts(54)
# 1211  execute Account curation .executeCuration.publish
# 1212                              updateCuratedAccounts
# 1213                          query for merged accounts
# 1214                                  Build search tags
# 1215              Building search tag table for ACCOUNT
# 1216                        updating account custodians
# 1217  Completing state update for autocuration proce...
#
#                               START_TIME    ID  THREAD_ID   DP_ID  \
# 0     2019-01-03 22:58:55.7000000 +00:00     1        133       3
# 1     2019-01-03 22:59:10.4150000 +00:00     2        139       5
# 2     2019-01-03 22:59:25.3790000 +00:00     3        144       7
# 3     2019-01-03 22:59:40.5030000 +00:00     4        167       9
# 4     2019-01-03 23:02:55.4530000 +00:00     5        201       9
# 5     2019-01-03 23:03:02.5590000 +00:00     6        201       9
# 6     2019-01-03 23:07:40.4240000 +00:00     7        253       5
# 7     2019-01-03 23:11:10.3880000 +00:00     8        294       7
# 8     2019-01-03 23:11:10.5610000 +00:00     9        294  (null)
# 9     2019-01-03 23:11:10.8590000 +00:00    10        294       7
# 10    2019-01-03 23:11:10.8640000 +00:00    11        294       7
# 11    2019-01-03 23:11:10.8850000 +00:00    12        294  (null)
# 12    2019-01-03 23:11:10.9030000 +00:00    13        294       7
# 13    2019-01-03 23:11:10.9740000 +00:00    14        294       7
# 14    2019-01-03 23:11:10.9970000 +00:00    15        294       7
# 15    2019-01-03 23:11:11.0460000 +00:00    16        294  (null)
# 16    2019-01-03 23:11:11.0700000 +00:00    17        294       7
# 17    2019-01-03 23:11:11.1630000 +00:00    18        294       7
# 18    2019-01-03 23:11:11.1960000 +00:00    19        294  (null)
# 19    2019-01-03 23:11:11.2160000 +00:00    20        294       7
# 20    2019-01-03 23:11:12.1150000 +00:00    21        294       7
# 21    2019-01-03 23:11:12.1370000 +00:00    22        294  (null)
# 22    2019-01-03 23:11:12.1550000 +00:00    23        294       7
# 23    2019-01-03 23:11:12.1650000 +00:00    24        294       7
# 24    2019-01-03 23:11:12.1900000 +00:00    25        294  (null)
# 25    2019-01-03 23:11:12.2500000 +00:00    26        294       7
# 26    2019-01-03 23:11:12.2610000 +00:00    27        294       7
# 27    2019-01-03 23:11:12.2880000 +00:00    28        294  (null)
# 28    2019-01-03 23:11:12.3050000 +00:00    29        294       7
# 29    2019-01-03 23:13:25.3070000 +00:00    30        294       3
# ...                                  ...   ...        ...     ...
# 1186  2019-01-05 10:37:25.2840000 +00:00  1187       1395     128
# 1187  2019-01-14 22:50:05.2940000 +00:00  1188      18091  (null)
# 1188  2019-01-15 10:55:22.6710000 +00:00  1189      18091  (null)
# 1189  2019-01-15 10:55:22.8980000 +00:00  1190      18091  (null)
# 1190  2019-01-15 10:55:29.7460000 +00:00  1191      18091  (null)
# 1191  2019-01-15 10:55:29.8090000 +00:00  1192      18091  (null)
# 1192  2019-01-15 16:04:39.1060000 +00:00  1193       3799     172
# 1193  2019-01-15 16:04:39.1180000 +00:00  1194       3799     172
# 1195  2019-01-15 16:04:39.2590000 +00:00  1196       3799     172
# 1196  2019-01-15 16:04:39.2630000 +00:00  1197       3799     172
# 1197  2019-01-15 16:04:39.2690000 +00:00  1198       3799     172
# 1198  2019-01-15 16:04:39.3160000 +00:00  1199       3799     172
# 1199  2019-01-15 16:04:39.3190000 +00:00  1200       3799     172
# 1200  2019-01-15 16:04:39.4620000 +00:00  1201       3799     172
# 1201  2019-01-15 16:04:39.5050000 +00:00  1202       3799     172
# 1202  2019-01-15 16:04:39.6660000 +00:00  1203       3799  (null)
# 1203  2019-01-15 16:04:39.8110000 +00:00  1204       3799     172
# 1204  2019-01-15 16:04:39.8300000 +00:00  1205       3799     172
# 1205  2019-01-15 19:19:43.3460000 +00:00  1206        128     173
# 1206  2019-01-15 19:19:43.3490000 +00:00  1207        128     173
# 1208  2019-01-15 19:19:43.3830000 +00:00  1209        128     173
# 1209  2019-01-15 19:19:43.3850000 +00:00  1210        128     173
# 1210  2019-01-15 19:19:43.3870000 +00:00  1211        128     173
# 1211  2019-01-15 19:19:43.4920000 +00:00  1212        128     173
# 1212  2019-01-15 19:19:43.4940000 +00:00  1213        128     173
# 1213  2019-01-15 19:19:43.4970000 +00:00  1214        128     173
# 1214  2019-01-15 19:19:43.5110000 +00:00  1215        128     173
# 1215  2019-01-15 19:19:43.5630000 +00:00  1216        128  (null)
# 1216  2019-01-15 19:19:43.6900000 +00:00  1217        128     173
# 1217  2019-01-15 19:19:43.7000000 +00:00  1218        128     173
#
#      PARENT_LOG_ID  OPS_SEQUENCE
# 0           (null)             5
# 1           (null)             5
# 2           (null)             5
# 3           (null)             5
# 4           (null)             5
# 5                5             5
# 6           (null)             5
# 7           (null)             5
# 8           (null)             5
# 9           (null)             5
# 10          (null)             5
# 11          (null)             5
# 12          (null)             5
# 13          (null)             5
# 14              14             5
# 15          (null)             5
# 16          (null)             5
# 17          (null)             5
# 18          (null)             5
# 19          (null)             5
# 20          (null)             5
# 21          (null)             5
# 22          (null)             5
# 23          (null)             5
# 24          (null)             5
# 25          (null)             5
# 26          (null)             5
# 27          (null)             5
# 28          (null)             5
# 29          (null)             5
# ...            ...           ...
# 1186        (null)             5
# 1187        (null)             5
# 1188        (null)             5
# 1189        (null)             5
# 1190        (null)             5
# 1191        (null)             5
# 1192        (null)             5
# 1193        (null)             5
# 1195        (null)             5
# 1196          1196             5
# 1197        (null)             5
# 1198          1196             5
# 1199        (null)             5
# 1200        (null)             5
# 1201        (null)             5
# 1202        (null)             5
# 1203        (null)             5
# 1204        (null)             5
# 1205        (null)             5
# 1206        (null)             5
# 1208        (null)             5
# 1209          1209             5
# 1210        (null)             5
# 1211          1209             5
# 1212        (null)             5
# 1213        (null)             5
# 1214        (null)             5
# 1215        (null)             5
# 1216        (null)             5
# 1217        (null)             5
#
# [1216 rows x 9 columns]

# %% [markdown]
# # Making a narrower Dataset

# %%
perflog_df_narrow = perflog_df_no_nulls[['MONITOR', 'ELAPSED']]

# %%
perflog_df_no_nulls.ELAPSED
# Out:
# 0         863193
# 1         497613
# 2         694162
# 3         189452
# 4        2664626
# 5         700134
# 6        1899577
# 7             29
# 8            294
# 9              2
# 10            16
# 11            14
# 12            66
# 13            66
# 14            27
# 15            20
# 16            38
# 17            27
# 18            17
# 19           896
# 20            17
# 21            14
# 22             6
# 23            20
# 24            19
# 25             6
# 26            21
# 27            15
# 28             3
# 29       1319606
#           ...
# 1186           7
# 1187    43517206
# 1188         225
# 1189        6845
# 1190          49
# 1191        4748
# 1192           8
# 1193          15
# 1195         562
# 1196          49
# 1197          36
# 1198         502
# 1199         182
# 1200          11
# 1201         302
# 1202         136
# 1203           4
# 1204          15
# 1205           2
# 1206           9
# 1208         314
# 1209         104
# 1210          99
# 1211         202
# 1212          14
# 1213           8
# 1214         176
# 1215         120
# 1216           2
# 1217          10
# Name: ELAPSED, Length: 1216, dtype: object

# %%
perflog_df_narrow.to_csv('clean_perf_log.csv')

# %%
# %cat clean_perf_log.csv
# Out:
# ,MONITOR,ELAPSED
# 0,DCS.collectData,863193
# 1,DCS.collectData,497613
# 2,DCS.collectData,694162
# 3,DCS.collectData,189452
# 4,transformEntityType PERMISSION,2664626
# 5,transformToPermission,700134
# 6,transformEntityType ACCOUNT,1899577
# 7,transformEntityType APPLICATION,29
# 8,post-transform DbPerfUtil.updateTableStatistics,294
# 9,removeDuplicateEntity APPLICATION,2
# 10,transformEntityType ACCOUNT,16
# 11,post-transform DbPerfUtil.updateTableStatistics,14
# 12,removeDuplicateEntity ACCOUNT,66
# 13,transformEntityType PERMISSION,66
# 14,transformToPermission,27
# 15,post-transform DbPerfUtil.updateTableStatistics,20
# 16,removeDuplicateEntity PERMISSION,38
# 17,transformEntityType PERMISSION_TO_HOLDERS,27
# 18,post-transform DbPerfUtil.updateTableStatistics,17
# 19,removeDuplicateEntity PERMISSION_TO_HOLDERS,896
# 20,transformEntityType PERMISSIONS_FROM_HOLDER,17
# 21,post-transform DbPerfUtil.updateTableStatistics,14
# 22,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,6
# 23,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,20
# 24,post-transform DbPerfUtil.updateTableStatistics,19
# 25,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,6
# 26,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,21
# 27,post-transform DbPerfUtil.updateTableStatistics,15
# 28,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,3
# 29,transformEntityType USER,1319606
# 30,transformToPermission,687396
# 31,transformToPermission,713807
# 32,post-transform DbPerfUtil.updateTableStatistics,1175
# 33,removeDuplicateEntity USER,428
# 34,transformEntityType GROUP,1717865
# 35,transformToPermission,545826
# 36,post-transform DbPerfUtil.updateTableStatistics,491
# 37,removeDuplicateEntity ACCOUNT,6253
# 38,post-transform DbPerfUtil.updateTableStatistics,23
# 39,removeDuplicateEntity PERMISSION,667
# 40,transformEntityType PERMISSION_TO_HOLDERS,208
# 41,post-transform DbPerfUtil.updateTableStatistics,10
# 42,removeDuplicateEntity PERMISSION_TO_HOLDERS,13092
# 43,transformEntityType PERMISSIONS_FROM_HOLDER,671
# 44,post-transform DbPerfUtil.updateTableStatistics,211
# 45,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,9899
# 46,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,218
# 47,post-transform DbPerfUtil.updateTableStatistics,15
# 48,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,6
# 49,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,275
# 50,post-transform DbPerfUtil.updateTableStatistics,92
# 51,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,102
# 52,post-transform DbPerfUtil.updateTableStatistics,16
# 53,removeDuplicateEntity GROUP,667
# 54,transformEntityType GROUPMEMBERSHIP,31
# 55,post-transform DbPerfUtil.updateTableStatistics,13
# 56,removeDuplicateEntity GROUPMEMBERSHIP,3
# 57,transformEntityType GROUPTOGROUP,199
# 58,post-transform DbPerfUtil.updateTableStatistics,14143
# 59,removeDuplicateEntity GROUPTOGROUP,397
# 60,resolveGroupToGroupMemberships,3826
# 61,JoinAttributeValidation.validateJoinAttribute,53
# 62,NontrivialUnification.unify,9961523
# 63,TrivialUserGeneration.createSUsersWithExistingUniqueId,79
# 64,TrivialUserGeneration.createSUsersWithoutExistingUniqueId,9960828
# 65,before:resolveNullUniqueUserIds.DbPerfUtil.updateTableStatistics,22
# 66,resolveNullUniqueUserIds.Query,483
# 67,resolveNullUniqueUserIds.Process,1
# 68,Unification-PhaseI.DbPerfUtil.updateTableStatistics,9
# 69,analyzeUnification,1772
# 70,SnapshotDAO.realizeUnificationSnapshot,163247
# 71,UserRefResolution.resolveUserReferences,32430
# 72,resolveUserReferences.populateSUserJoinAttributes,3396
# 73,resolveUserReferences.DbPerfUtil.updateTableStatistics,11
# 74,resolveUserReferences.removeAmbiguousSUserJoinAttributes,445
# 75,resolveUserReferences.resolveSupervisorsDirectly,1270
# 76,resolveUserReferences.resolveOwners,91
# 77,resolveUserReferences.UserDerivedAttrResolution.resolve,27078
# 78,TransitiveSubgroups.generate,40
# 79,TransitiveSubgroups.generate (distance=1),32
# 80,Publication.publish,249650
# 81,publish.MergeEntities.merge,861
# 82,MergeEntities.mergeEntities (USER),157
# 83,MergeEntities:UserDerivedAttrResolution.resolve,80
# 84,MergeEntities.mergeIDMUserInfoFromPriorVersion,4
# 85,publish.PermissionsOwnerUnlinker.unlinkDeletedSusersFromPermissionOwners,60
# 86,publish.AccountsOwnerUnlinker.unlinkDeletedSusersFromAccountOwners,112
# 87,publish.AccountRelationTypeUtil.populateAccountRelationTypes,88
# 88,publish.TagBuilder.buildSearchTag,224012
# 89,EntityTagBuilder: Building search tags for USER,194744
# 90,EntityTagBuilder: Building search tags for GROUP,29238
# 91,publish.ApplicationSummaries.populateApplicationSummary,484
# 92,initApplicationSummary,224
# 93,updatePermissionCount,51
# 94,updateAccountCount,92
# 95,updateDanglingAccountCount,73
# 96,updateSharedAccountCount,20
# 97,publish.EntityChanges.addEntityChanges,6121
# 98, EntityChanges: EntityChanges.genAddedAppls ,48
# 99, EntityChanges: EntityChanges.genAddedPerms ,49
# 100, EntityChanges: EntityChanges.genAddedUsers ,6006
# 101,publish.SnapshotDAO.updatepublishStateOnCollections ,29
# 102,publish.publishSnapshot,17736
# 103,publish.TagBuilder.cleanupIdentitySearchTagTables,2
# 104,Publish.DbPerfUtil.updateTableStatistics,21
# 105,Detect ALL Technical Roles,22
# 106,Detect ALL SoDs,15
# 107,runResolutionPhase1: DbPerfUtil.updateTableStatistics,62
# 108,runResolution.ResolveCollectedAccounts.resolve,22055
# 109,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,42
# 110,runResolutionPhase1: DbPerfUtil.updateTableStatistics,19
# 111,runResolution.IdentityManagerResolution.handleIDMPermissionExceptions,349
# 112,handleIDMPermissionExceptions.ResolveIDMAccounts.deleteProblemIDMAccounts,233
# 113,handleIDMPermissionExceptions.ResolveIDMPermissions.deleteProblemIDMPermissions,107
# 114,runResolution.IdentityManagerResolution.resolveAccountsAndPermissions,213
# 115,resolveAccountsAndPermissions.ResolveCollectedProvApplications.resolve ,10
# 116,resolveAccountsAndPermissions.ResolveIDMAccounts.resolveAccountToProvApp,58
# 117,resolveAccountsAndPermissions.ResolveIDMPermissions.resolvePermissionToProvApp,70
# 118,resolveAccountsAndPermissions.ResolveIDMPermissions.updateIDMBoundResourceParamName,38
# 119,resolveAccountsAndPermissions.ResolveIDMPermissions.resolveIDMPermissionFlags,20
# 120,runResolution.ResolveCollectedAccounts.resolve,9389
# 121,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,829
# 122,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,136
# 123,runResolution.ResolveAccountOwners.resolve,5
# 124,runResolution.DbPerfUtil.updateTableStatistics,11
# 125,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,34
# 126,runResolution.ResolveCollectedPermissions.resolve,21
# 127,runResolution.ResolvePermissionsOwners.resolve,8
# 128,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,17793
# 129,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,246
# 130,runResolution.ResolveAccountOwners.resolve,154
# 131,runResolution.DbPerfUtil.updateTableStatistics,1094
# 132,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,126
# 133,runResolution.ResolveCollectedPermissions.resolve,19384
# 134,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,14123
# 135,runResolutionPhase1: DbPerfUtil.updateTableStatistics,31
# 136,runResolution.ResolveCollectedAccounts.resolve,13
# 137,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,51
# 138,runResolution.ResolveAccountOwners.resolve,13
# 139,runResolution.DbPerfUtil.updateTableStatistics,540
# 140,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,26251
# 141,TransitivePermissions.populateDistance1,420
# 142,TransitivePermissions.populateDirect,26
# 143,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,18
# 144,resolvePermissionToHolder.ResolveUtil.createUserPermissions,2168
# 145,createUserPermissions.createTPermissionUsers,1996
# 146,createUserPermissions.updateTableStatistics#1,15
# 147,createUserPermissions.createVirtualAccounts,66
# 148,createUserPermissions.createSAccountUsers,37
# 149,createUserPermissions.updateTableStatistics#2,11
# 150,createUserPermissions.createVirtualAccountPermissions,13
# 151,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,2771
# 152,runResolutionPhase2: DbPerfUtil.updateTableStatistics,54
# 153,publish.MergeEntities.merge,665
# 154,MergeEntities.mergeEntities (PERMISSION),32
# 155,MergeEntities.mergeEntities (ACCOUNT),616
# 156,publish.TagBuilder.buildSearchTag,459197
# 157,EntityTagBuilder: Building search tags for ACCOUNT,458354
# 158,runResolution.ResolvePermissionsOwners.resolve,13680
# 159,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,4839
# 160,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,68
# 161,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,544
# 162,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,8172
# 163,runResolution.ResolveCollectedPermissions.resolve,1347288
# 164,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,20723
# 165,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,173
# 166,TransitivePermissions.populateDistance1,36
# 167,TransitivePermissions.populateDirect,3
# 168,runResolution.AccountGrantPermission.resolve,29
# 169,runResolution.IdentityManagerResolution.resolveRolesToApplication,49
# 170,resolveRolesToApplication.ResolveIDMPermissions.resolveRolesToProvisoningApplication,43
# 171,runResolution.IdentityManagerResolution.resolveARResources,55
# 172,runResolutionPhase2: DbPerfUtil.updateTableStatistics,7758
# 173,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,27
# 174,resolvePermissionToHolder.ResolveUtil.createUserPermissions,1322932
# 175,createUserPermissions.createTPermissionUsers,83535
# 176,createUserPermissions.updateTableStatistics#1,50
# 177,createUserPermissions.createVirtualAccounts,35129
# 178,createUserPermissions.createSAccountUsers,12788
# 179,createUserPermissions.updateTableStatistics#2,92
# 180,createUserPermissions.createVirtualAccountPermissions,225946
# 181,EntityTagBuilder: Building search tags for PERMISSION,346
# 182,publish.ApplicationSummaries.populateApplicationSummary,110308
# 183,initApplicationSummary,5
# 184,updatePermissionCount,69
# 185,updateAccountCount,169
# 186,updateDanglingAccountCount,309
# 187,updateSharedAccountCount,912
# 188,addPermissionChanges,206
# 189,updatePermissionChangeCount,18
# 190,addAccountChanges,100686
# 191,updateAccountChangeCount,3836
# 192,publish.EntityChanges.addEntityChanges,4073
# 193, EntityChanges: EntityChanges.genAddedAppls ,506
# 194, EntityChanges: EntityChanges.genAddedPerms ,181
# 195, EntityChanges: EntityChanges.genAddedUsers ,413
# 196, EntityChanges: EntityChanges.genAlteredPerms ,109
# 197, EntityChanges: EntityChanges.genAlteredUsers ,21
# 198, EntityChanges: EntityChanges.genRemovedPerms ,80
# 199, EntityChanges: EntityChanges.genRemovedUsers ,371
# 200, EntityChanges: EntityChanges.genRemovedAppls ,43
# 201,publish.SnapshotDAO.updatepublishStateOnCollections ,51
# 202,publish.publishSnapshot,273852
# 203,publish.TagBuilder.cleanupAppSearchTagTables,485
# 204,Publish.DbPerfUtil.updateTableStatistics,2883
# 205,Detect ALL Technical Roles,12
# 206,Detect ALL SoDs,7
# 207,DCS.collectData,1764056
# 208,publish.MergeEntities.merge,169
# 209,MergeEntities.mergeEntities (PERMISSION),67
# 210,MergeEntities.mergeEntities (ACCOUNT),80
# 211,publish.TagBuilder.buildSearchTag,571
# 212,EntityTagBuilder: Building search tags for ACCOUNT,14
# 213,EntityTagBuilder: Building search tags for PERMISSION,453
# 214,publish.ApplicationSummaries.populateApplicationSummary,24569
# 215,initApplicationSummary,9
# 216,updatePermissionCount,77
# 217,updateAccountCount,637
# 218,updateDanglingAccountCount,814
# 219,updateSharedAccountCount,1556
# 220,addPermissionChanges,454
# 221,updatePermissionChangeCount,17
# 222,addAccountChanges,20583
# 223,updateAccountChangeCount,5
# 224,publish.EntityChanges.addEntityChanges,1741
# 225, EntityChanges: EntityChanges.genAddedAppls ,6
# 226, EntityChanges: EntityChanges.genAddedPerms ,53
# 227, EntityChanges: EntityChanges.genAddedUsers ,1007
# 228, EntityChanges: EntityChanges.genAlteredPerms ,28
# 229, EntityChanges: EntityChanges.genAlteredUsers ,5
# 230, EntityChanges: EntityChanges.genRemovedPerms ,32
# 231, EntityChanges: EntityChanges.genRemovedUsers ,579
# 232, EntityChanges: EntityChanges.genRemovedAppls ,3
# 233,publish.SnapshotDAO.updatepublishStateOnCollections ,24
# 234,publish.publishSnapshot,1745
# 235,publish.TagBuilder.cleanupAppSearchTagTables,1080
# 236,Publish.DbPerfUtil.updateTableStatistics,2268
# 237,Detect ALL Technical Roles,23
# 238,Detect ALL SoDs,16
# 239,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,3469
# 240,runResolution.ResolvePermissionsOwners.resolve,21457
# 241,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,18351
# 242,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,445
# 243,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,234
# 244,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,2842
# 245,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,5251
# 246,TransitivePermissions.populateDistance1,14
# 247,TransitivePermissions.populateDirect,3
# 248,runResolutionPhase2: DbPerfUtil.updateTableStatistics,28
# 249,publish.MergeEntities.merge,217
# 250,MergeEntities.mergeEntities (PERMISSION),72
# 251,MergeEntities.mergeEntities (ACCOUNT),134
# 252,publish.TagBuilder.buildSearchTag,49997
# 253,EntityTagBuilder: Building search tags for ACCOUNT,83
# 254,EntityTagBuilder: Building search tags for PERMISSION,49888
# 255,publish.ApplicationSummaries.populateApplicationSummary,15061
# 256,initApplicationSummary,4
# 257,updatePermissionCount,66
# 258,updateAccountCount,159
# 259,updateDanglingAccountCount,478
# 260,updateSharedAccountCount,666
# 261,addPermissionChanges,5144
# 262,updatePermissionChangeCount,63
# 263,addAccountChanges,8392
# 264,updateAccountChangeCount,26
# 265,publish.EntityChanges.addEntityChanges,771
# 266, EntityChanges: EntityChanges.genAddedAppls ,4
# 267, EntityChanges: EntityChanges.genAddedPerms ,15
# 268, EntityChanges: EntityChanges.genAddedUsers ,295
# 269, EntityChanges: EntityChanges.genAlteredPerms ,25
# 270, EntityChanges: EntityChanges.genAlteredUsers ,4
# 271, EntityChanges: EntityChanges.genRemovedPerms ,62
# 272, EntityChanges: EntityChanges.genRemovedUsers ,342
# 273, EntityChanges: EntityChanges.genRemovedAppls ,3
# 274,publish.SnapshotDAO.updatepublishStateOnCollections ,4
# 275,publish.publishSnapshot,6346
# 276,publish.TagBuilder.cleanupAppSearchTagTables,432
# 277,Publish.DbPerfUtil.updateTableStatistics,25
# 278,Detect ALL Technical Roles,60
# 279,Detect ALL SoDs,17
# 280,transformEntityType USER,804851
# 281,post-transform DbPerfUtil.updateTableStatistics,745
# 282,removeDuplicateEntity USER,154
# 283,transformEntityType GROUP,1319694
# 284,post-transform DbPerfUtil.updateTableStatistics,25436
# 285,removeDuplicateEntity GROUP,3114
# 286,transformEntityType GROUPMEMBERSHIP,178
# 287,post-transform DbPerfUtil.updateTableStatistics,13
# 288,removeDuplicateEntity GROUPMEMBERSHIP,1
# 289,transformEntityType GROUPTOGROUP,852
# 290,post-transform DbPerfUtil.updateTableStatistics,18
# 291,removeDuplicateEntity GROUPTOGROUP,2
# 292,resolveGroupToGroupMemberships,135
# 293,DCS.collectData,1086478
# 294,transformEntityType USER,558912
# 295,post-transform DbPerfUtil.updateTableStatistics,772
# 296,removeDuplicateEntity USER,62
# 297,transformEntityType GROUP,2653262
# 298,post-transform DbPerfUtil.updateTableStatistics,1328
# 299,removeDuplicateEntity GROUP,47322
# 300,transformEntityType GROUPMEMBERSHIP,1102
# 301,post-transform DbPerfUtil.updateTableStatistics,123
# 302,removeDuplicateEntity GROUPMEMBERSHIP,317
# 303,transformEntityType GROUPTOGROUP,67663
# 304,post-transform DbPerfUtil.updateTableStatistics,19
# 305,removeDuplicateEntity GROUPTOGROUP,2
# 306,resolveGroupToGroupMemberships,168
# 307,JoinAttributeValidation.validateJoinAttribute,18
# 308,NontrivialUnification.unify,23937238
# 309,TrivialUserGeneration.createSUsersWithExistingUniqueId,9334287
# 310,TrivialUserGeneration.createSUsersWithoutExistingUniqueId,285
# 311,NonTrivialUserGeneration.clearJoinAttributeTables,41
# 312,NonTrivialUserGeneration.populateSUserJoinAttributes,167813
# 313,NonTrivialUserGeneration.populateCUserJoinAttributes,77244
# 314,NonTrivialUserGeneration.findCUserUniqueUserIds,489
# 315,NonTrivialUserGeneration.updateSUsersFromJoinedCUsers.Query,631
# 316,NonTrivialUserGeneration.updateSUsersFromJoinedCUsers.Process,2
# 317,NonTrivialUserGeneration.flagUnmatchedCUsersWithMatchingUniqueId.Query,347
# 318,NonTrivialUserGeneration.flagUnmatchedCUsersWithMatchingUniqueId.Process,2
# 319,NonTrivialUserGeneration.createSUsersFromUnjoinedCUsers.Query,730
# 320,NonTrivialUserGeneration.createSUsersFromUnjoinedCUsers.Process,14076528
# 321,before:resolveNullUniqueUserIds.DbPerfUtil.updateTableStatistics,3421
# 322,resolveNullUniqueUserIds.Query,2540
# 323,resolveNullUniqueUserIds.Process,272749
# 324,Unification-PhaseI.DbPerfUtil.updateTableStatistics,440
# 325,analyzeUnification,648
# 326,SnapshotDAO.realizeUnificationSnapshot,125689
# 327,UserRefResolution.resolveUserReferences,41630
# 328,resolveUserReferences.populateSUserJoinAttributes,6413
# 329,resolveUserReferences.DbPerfUtil.updateTableStatistics,449
# 330,resolveUserReferences.removeAmbiguousSUserJoinAttributes,241
# 331,resolveUserReferences.resolveSupervisorsDirectly,6450
# 332,resolveUserReferences.resolveOwners,426
# 333,resolveUserReferences.UserDerivedAttrResolution.resolve,26595
# 334,TransitiveSubgroups.generate,61
# 335,TransitiveSubgroups.generate (distance=1),23
# 336,Publication.publish,1103128
# 337,publish.MergeEntities.merge,315
# 338,MergeEntities.mergeEntities (USER),159
# 339,MergeEntities:UserDerivedAttrResolution.resolve,125
# 340,MergeEntities.mergeIDMUserInfoFromPriorVersion,6
# 341,publish.PermissionsOwnerUnlinker.unlinkDeletedSusersFromPermissionOwners,35
# 342,publish.AccountsOwnerUnlinker.unlinkDeletedSusersFromAccountOwners,93
# 343,publish.AccountRelationTypeUtil.populateAccountRelationTypes,20357
# 344,publish.TagBuilder.buildSearchTag,391954
# 345,EntityTagBuilder: Building search tags for USER,300324
# 346,EntityTagBuilder: Building search tags for GROUP,91606
# 347,publish.ApplicationSummaries.populateApplicationSummary,13123
# 348,initApplicationSummary,4
# 349,updatePermissionCount,67
# 350,updateAccountCount,707
# 351,updateDanglingAccountCount,349
# 352,updateSharedAccountCount,479
# 353,addPermissionChanges,4620
# 354,updatePermissionChangeCount,268
# 355,addAccountChanges,6587
# 356,updateAccountChangeCount,4
# 357,publish.EntityChanges.addEntityChanges,544467
# 358, EntityChanges: EntityChanges.genAddedAppls ,70
# 359, EntityChanges: EntityChanges.genAddedPerms ,53
# 360, EntityChanges: EntityChanges.genAddedUsers ,3097
# 361, EntityChanges: EntityChanges.genAlteredPerms ,191
# 362, EntityChanges: EntityChanges.genAlteredUsers ,540076
# 363, EntityChanges: EntityChanges.genRemovedPerms ,348
# 364, EntityChanges: EntityChanges.genRemovedUsers ,568
# 365, EntityChanges: EntityChanges.genRemovedAppls ,41
# 366,publish.SnapshotDAO.updatepublishStateOnCollections ,28
# 367,publish.publishSnapshot,76673
# 368,publish.TagBuilder.cleanupIdentitySearchTagTables,4175
# 369,Publish.DbPerfUtil.updateTableStatistics,10
# 370,Detect ALL Technical Roles,9
# 371,Detect ALL SoDs,8
# 372,DCS.collectData,450338
# 373,transformEntityType APPLICATION,142
# 374,post-transform DbPerfUtil.updateTableStatistics,24
# 375,removeDuplicateEntity APPLICATION,2
# 376,transformEntityType ACCOUNT,13
# 377,post-transform DbPerfUtil.updateTableStatistics,12
# 378,removeDuplicateEntity ACCOUNT,273
# 379,transformEntityType PERMISSION,867
# 380,transformToPermission,843
# 381,post-transform DbPerfUtil.updateTableStatistics,790
# 382,removeDuplicateEntity PERMISSION,107
# 383,transformEntityType PERMISSION_TO_HOLDERS,15
# 384,post-transform DbPerfUtil.updateTableStatistics,12
# 385,removeDuplicateEntity PERMISSION_TO_HOLDERS,10592
# 386,transformEntityType PERMISSIONS_FROM_HOLDER,13
# 387,post-transform DbPerfUtil.updateTableStatistics,10
# 388,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,281
# 389,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,14
# 390,post-transform DbPerfUtil.updateTableStatistics,12
# 391,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,2
# 392,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,18
# 393,post-transform DbPerfUtil.updateTableStatistics,28
# 394,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,2
# 395,runResolutionPhase1: DbPerfUtil.updateTableStatistics,12
# 396,runResolution.IdentityManagerResolution.handleIDMPermissionExceptions,268
# 397,handleIDMPermissionExceptions.ResolveIDMAccounts.deleteProblemIDMAccounts,208
# 398,handleIDMPermissionExceptions.ResolveIDMPermissions.deleteProblemIDMPermissions,53
# 399,runResolution.IdentityManagerResolution.resolveAccountsAndPermissions,441
# 400,resolveAccountsAndPermissions.ResolveCollectedProvApplications.resolve ,3
# 401,resolveAccountsAndPermissions.ResolveIDMAccounts.resolveAccountToProvApp,193
# 402,resolveAccountsAndPermissions.ResolveIDMPermissions.resolvePermissionToProvApp,53
# 403,resolveAccountsAndPermissions.ResolveIDMPermissions.updateIDMBoundResourceParamName,11
# 404,resolveAccountsAndPermissions.ResolveIDMPermissions.resolveIDMPermissionFlags,169
# 405,runResolution.ResolveCollectedAccounts.resolve,11080
# 406,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,18
# 407,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,23
# 408,runResolution.ResolveAccountOwners.resolve,5
# 409,runResolution.DbPerfUtil.updateTableStatistics,17
# 410,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,66
# 411,runResolution.ResolveCollectedPermissions.resolve,10323
# 412,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,6687
# 413,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,50
# 414,resolvePermissionToHolder.ResolveUtil.createUserPermissions,554
# 415,createUserPermissions.createTPermissionUsers,285
# 416,createUserPermissions.updateTableStatistics#1,9
# 417,createUserPermissions.createVirtualAccounts,207
# 418,createUserPermissions.createSAccountUsers,15
# 419,createUserPermissions.updateTableStatistics#2,10
# 420,createUserPermissions.createVirtualAccountPermissions,12
# 421,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,3049
# 422,runResolution.ResolvePermissionsOwners.resolve,12380
# 423,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,9149
# 424,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,344
# 425,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,146
# 426,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,3061
# 427,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,100
# 428,TransitivePermissions.populateDistance1,30
# 429,TransitivePermissions.populateDirect,3
# 430,runResolution.AccountGrantPermission.resolve,9
# 431,runResolution.IdentityManagerResolution.resolveRolesToApplication,46
# 432,resolveRolesToApplication.ResolveIDMPermissions.resolveRolesToProvisoningApplication,37
# 433,runResolution.IdentityManagerResolution.resolveARResources,53
# 434,runResolutionPhase2: DbPerfUtil.updateTableStatistics,23
# 435,publish.MergeEntities.merge,74
# 436,MergeEntities.mergeEntities (PERMISSION),35
# 437,MergeEntities.mergeEntities (ACCOUNT),29
# 438,publish.TagBuilder.buildSearchTag,135
# 439,EntityTagBuilder: Building search tags for ACCOUNT,10
# 440,EntityTagBuilder: Building search tags for PERMISSION,105
# 441,publish.ApplicationSummaries.populateApplicationSummary,13087
# 442,initApplicationSummary,4
# 443,updatePermissionCount,66
# 444,updateAccountCount,621
# 445,updateDanglingAccountCount,368
# 446,updateSharedAccountCount,578
# 447,addPermissionChanges,4497
# 448,updatePermissionChangeCount,253
# 449,addAccountChanges,6629
# 450,updateAccountChangeCount,12
# 451,publish.EntityChanges.addEntityChanges,2804
# 452, EntityChanges: EntityChanges.genAddedAppls ,50
# 453, EntityChanges: EntityChanges.genAddedPerms ,120
# 454, EntityChanges: EntityChanges.genAddedUsers ,1141
# 455, EntityChanges: EntityChanges.genAlteredPerms ,173
# 456, EntityChanges: EntityChanges.genAlteredUsers ,4
# 457, EntityChanges: EntityChanges.genRemovedPerms ,234
# 458, EntityChanges: EntityChanges.genRemovedUsers ,1011
# 459, EntityChanges: EntityChanges.genRemovedAppls ,50
# 460,publish.SnapshotDAO.updatepublishStateOnCollections ,4
# 461,publish.publishSnapshot,1732
# 462,publish.TagBuilder.cleanupAppSearchTagTables,520
# 463,Publish.DbPerfUtil.updateTableStatistics,74
# 464,Detect ALL Technical Roles,9
# 465,Detect ALL SoDs,7
# 466,DCS.collectData,288808
# 467,transformEntityType ACCOUNT,1067082
# 468,post-transform DbPerfUtil.updateTableStatistics,1325
# 469,removeDuplicateEntity ACCOUNT,12451
# 470,runResolutionPhase1: DbPerfUtil.updateTableStatistics,31
# 471,runResolution.ResolveCollectedAccounts.resolve,25072
# 472,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,25
# 473,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,142
# 474,runResolution.ResolveAccountOwners.resolve,5
# 475,runResolution.DbPerfUtil.updateTableStatistics,15
# 476,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,44
# 477,runResolution.ResolveCollectedPermissions.resolve,8
# 478,runResolution.ResolvePermissionsOwners.resolve,4
# 479,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,17717
# 480,TransitivePermissions.populateDistance1,40
# 481,TransitivePermissions.populateDirect,31
# 482,runResolutionPhase2: DbPerfUtil.updateTableStatistics,17
# 483,publish.MergeEntities.merge,168
# 484,MergeEntities.mergeEntities (PERMISSION),14
# 485,MergeEntities.mergeEntities (ACCOUNT),145
# 486,publish.TagBuilder.buildSearchTag,445036
# 487,EntityTagBuilder: Building search tags for ACCOUNT,445010
# 488,EntityTagBuilder: Building search tags for PERMISSION,4
# 489,publish.ApplicationSummaries.populateApplicationSummary,13471
# 490,initApplicationSummary,3
# 491,updatePermissionCount,44
# 492,updateAccountCount,162
# 493,updateDanglingAccountCount,352
# 494,updateSharedAccountCount,690
# 495,addPermissionChanges,4080
# 496,updatePermissionChangeCount,206
# 497,addAccountChanges,7895
# 498,updateAccountChangeCount,5
# 499,publish.EntityChanges.addEntityChanges,1519
# 500, EntityChanges: EntityChanges.genAddedAppls ,4
# 501, EntityChanges: EntityChanges.genAddedPerms ,60
# 502, EntityChanges: EntityChanges.genAddedUsers ,613
# 503, EntityChanges: EntityChanges.genAlteredPerms ,57
# 504, EntityChanges: EntityChanges.genAlteredUsers ,8
# 505, EntityChanges: EntityChanges.genRemovedPerms ,151
# 506, EntityChanges: EntityChanges.genRemovedUsers ,606
# 507, EntityChanges: EntityChanges.genRemovedAppls ,3
# 508,publish.SnapshotDAO.updatepublishStateOnCollections ,26
# 509,publish.publishSnapshot,33216
# 510,publish.TagBuilder.cleanupAppSearchTagTables,13528
# 511,Publish.DbPerfUtil.updateTableStatistics,144
# 512,Detect ALL Technical Roles,4
# 513,Detect ALL SoDs,4
# 514,DCS.collectData,129997
# 515,transformEntityType PERMISSION,1937129
# 516,transformToPermission,511451
# 517,transformToPermission,513487
# 518,transformToPermission,512824
# 519,transformToPermission,387504
# 520,post-transform DbPerfUtil.updateTableStatistics,5270
# 521,removeDuplicateEntity PERMISSION,7170
# 522,transformEntityType PERMISSION_TO_HOLDERS,38
# 523,post-transform DbPerfUtil.updateTableStatistics,19
# 524,removeDuplicateEntity PERMISSION_TO_HOLDERS,15564
# 525,transformEntityType PERMISSIONS_FROM_HOLDER,45
# 526,post-transform DbPerfUtil.updateTableStatistics,19
# 527,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,12184
# 528,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,41
# 529,post-transform DbPerfUtil.updateTableStatistics,20
# 530,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,2
# 531,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,39
# 532,post-transform DbPerfUtil.updateTableStatistics,18
# 533,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,1
# 534,runResolutionPhase1: DbPerfUtil.updateTableStatistics,22
# 535,runResolution.ResolveCollectedAccounts.resolve,6
# 536,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,239
# 537,runResolution.ResolveAccountOwners.resolve,9
# 538,runResolution.DbPerfUtil.updateTableStatistics,15
# 539,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,4680
# 540,runResolution.ResolveCollectedPermissions.resolve,1064167
# 541,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,9617
# 542,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,37
# 543,resolvePermissionToHolder.ResolveUtil.createUserPermissions,1049474
# 544,createUserPermissions.createTPermissionUsers,91405
# 545,createUserPermissions.updateTableStatistics#1,19
# 546,createUserPermissions.createVirtualAccounts,58370
# 547,createUserPermissions.createSAccountUsers,12254
# 548,createUserPermissions.updateTableStatistics#2,18
# 549,createUserPermissions.createVirtualAccountPermissions,193235
# 550,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,4888
# 551,runResolution.ResolvePermissionsOwners.resolve,26633
# 552,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,20188
# 553,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,542
# 554,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,608
# 555,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,5804
# 556,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,8218
# 557,TransitivePermissions.populateDistance1,39
# 558,TransitivePermissions.populateDirect,14
# 559,runResolutionPhase2: DbPerfUtil.updateTableStatistics,21
# 560,publish.MergeEntities.merge,336
# 561,MergeEntities.mergeEntities (PERMISSION),51
# 562,MergeEntities.mergeEntities (ACCOUNT),272
# 563,publish.TagBuilder.buildSearchTag,52024
# 564,EntityTagBuilder: Building search tags for ACCOUNT,153
# 565,EntityTagBuilder: Building search tags for PERMISSION,51845
# 566,publish.ApplicationSummaries.populateApplicationSummary,18021
# 567,initApplicationSummary,4
# 568,updatePermissionCount,109
# 569,updateAccountCount,183
# 570,updateDanglingAccountCount,385
# 571,updateSharedAccountCount,663
# 572,addPermissionChanges,8229
# 573,updatePermissionChangeCount,242
# 574,addAccountChanges,8157
# 575,updateAccountChangeCount,18
# 576,publish.EntityChanges.addEntityChanges,1743
# 577, EntityChanges: EntityChanges.genAddedAppls ,43
# 578, EntityChanges: EntityChanges.genAddedPerms ,105
# 579, EntityChanges: EntityChanges.genAddedUsers ,568
# 580, EntityChanges: EntityChanges.genAlteredPerms ,221
# 581, EntityChanges: EntityChanges.genAlteredUsers ,5
# 582, EntityChanges: EntityChanges.genRemovedPerms ,184
# 583, EntityChanges: EntityChanges.genRemovedUsers ,548
# 584, EntityChanges: EntityChanges.genRemovedAppls ,44
# 585,publish.SnapshotDAO.updatepublishStateOnCollections ,4
# 586,publish.publishSnapshot,205110
# 587,publish.TagBuilder.cleanupAppSearchTagTables,1470
# 588,Publish.DbPerfUtil.updateTableStatistics,145
# 589,Detect ALL Technical Roles,7
# 590,Detect ALL SoDs,7
# 591,DCS.collectData,600344
# 592,transformEntityType USER,816966
# 593,post-transform DbPerfUtil.updateTableStatistics,25377
# 594,removeDuplicateEntity USER,191
# 595,transformEntityType GROUP,4463106
# 596,DCS.collectData,1101807
# 597,transformEntityType USER,688386
# 598,post-transform DbPerfUtil.updateTableStatistics,8448
# 599,removeDuplicateEntity USER,67
# 600,transformEntityType GROUP,5658916
# 601,post-transform DbPerfUtil.updateTableStatistics,7595
# 602,removeDuplicateEntity GROUP,38890
# 603,transformEntityType GROUPMEMBERSHIP,1138
# 604,post-transform DbPerfUtil.updateTableStatistics,20
# 605,removeDuplicateEntity GROUPMEMBERSHIP,2
# 606,transformEntityType GROUPTOGROUP,13
# 607,post-transform DbPerfUtil.updateTableStatistics,12
# 608,removeDuplicateEntity GROUPTOGROUP,1
# 609,resolveGroupToGroupMemberships,122
# 610,JoinAttributeValidation.validateJoinAttribute,28
# 611,NontrivialUnification.unify,26841405
# 612,TrivialUserGeneration.createSUsersWithExistingUniqueId,10811920
# 613,post-transform DbPerfUtil.updateTableStatistics,81985
# 614,removeDuplicateEntity GROUP,1964
# 615,transformEntityType GROUPMEMBERSHIP,26
# 616,post-transform DbPerfUtil.updateTableStatistics,35
# 617,removeDuplicateEntity GROUPMEMBERSHIP,18
# 618,transformEntityType GROUPTOGROUP,91794
# 619,post-transform DbPerfUtil.updateTableStatistics,70
# 620,removeDuplicateEntity GROUPTOGROUP,6
# 621,resolveGroupToGroupMemberships,315
# 622,TrivialUserGeneration.createSUsersWithoutExistingUniqueId,983
# 623,NonTrivialUserGeneration.clearJoinAttributeTables,87
# 624,NonTrivialUserGeneration.populateSUserJoinAttributes,169679
# 625,NonTrivialUserGeneration.populateCUserJoinAttributes,78901
# 626,NonTrivialUserGeneration.findCUserUniqueUserIds,14301
# 627,NonTrivialUserGeneration.updateSUsersFromJoinedCUsers.Query,1848
# 628,NonTrivialUserGeneration.updateSUsersFromJoinedCUsers.Process,3
# 629,NonTrivialUserGeneration.flagUnmatchedCUsersWithMatchingUniqueId.Query,518
# 630,NonTrivialUserGeneration.flagUnmatchedCUsersWithMatchingUniqueId.Process,3
# 631,NonTrivialUserGeneration.createSUsersFromUnjoinedCUsers.Query,796
# 632,NonTrivialUserGeneration.createSUsersFromUnjoinedCUsers.Process,15758827
# 633,before:resolveNullUniqueUserIds.DbPerfUtil.updateTableStatistics,3372
# 634,resolveNullUniqueUserIds.Query,15
# 635,resolveNullUniqueUserIds.Process,2
# 636,Unification-PhaseI.DbPerfUtil.updateTableStatistics,11
# 637,analyzeUnification,789
# 638,SnapshotDAO.realizeUnificationSnapshot,148732
# 639,UserRefResolution.resolveUserReferences,68489
# 640,resolveUserReferences.populateSUserJoinAttributes,7498
# 641,resolveUserReferences.DbPerfUtil.updateTableStatistics,299
# 642,resolveUserReferences.removeAmbiguousSUserJoinAttributes,244
# 643,resolveUserReferences.resolveSupervisorsDirectly,14260
# 644,resolveUserReferences.resolveOwners,388
# 645,resolveUserReferences.UserDerivedAttrResolution.resolve,45599
# 646,TransitiveSubgroups.generate,97
# 647,TransitiveSubgroups.generate (distance=1),63
# 648,Publication.publish,2101873
# 649,publish.MergeEntities.merge,423
# 650,MergeEntities.mergeEntities (USER),220
# 651,MergeEntities:UserDerivedAttrResolution.resolve,169
# 652,MergeEntities.mergeIDMUserInfoFromPriorVersion,4
# 653,publish.PermissionsOwnerUnlinker.unlinkDeletedSusersFromPermissionOwners,39
# 654,publish.AccountsOwnerUnlinker.unlinkDeletedSusersFromAccountOwners,50
# 655,publish.AccountRelationTypeUtil.populateAccountRelationTypes,28867
# 656,publish.TagBuilder.buildSearchTag,497038
# 657,EntityTagBuilder: Building search tags for USER,380386
# 658,EntityTagBuilder: Building search tags for GROUP,116575
# 659,publish.ApplicationSummaries.populateApplicationSummary,14987
# 660,initApplicationSummary,159
# 661,updatePermissionCount,115
# 662,updateAccountCount,227
# 663,updateDanglingAccountCount,420
# 664,updateSharedAccountCount,588
# 665,addPermissionChanges,5479
# 666,updatePermissionChangeCount,217
# 667,addAccountChanges,7565
# 668,updateAccountChangeCount,163
# 669,publish.EntityChanges.addEntityChanges,1394951
# 670, EntityChanges: EntityChanges.genAddedAppls ,43
# 671, EntityChanges: EntityChanges.genAddedPerms ,88
# 672, EntityChanges: EntityChanges.genAddedUsers ,818
# 673, EntityChanges: EntityChanges.genAlteredPerms ,89
# 674, EntityChanges: EntityChanges.genAlteredUsers ,1392838
# 675, EntityChanges: EntityChanges.genRemovedPerms ,223
# 676, EntityChanges: EntityChanges.genRemovedUsers ,784
# 677, EntityChanges: EntityChanges.genRemovedAppls ,44
# 678,publish.SnapshotDAO.updatepublishStateOnCollections ,69
# 679,publish.publishSnapshot,107834
# 680,publish.TagBuilder.cleanupIdentitySearchTagTables,10134
# 681,Publish.DbPerfUtil.updateTableStatistics,1168
# 682,Detect ALL Technical Roles,7
# 683,Detect ALL SoDs,6
# 684,JoinAttributeValidation.validateJoinAttribute,15
# 685,NontrivialUnification.unify,29263019
# 686,TrivialUserGeneration.createSUsersWithExistingUniqueId,12155400
# 687,DCS.collectData,364372
# 688,transformEntityType ACCOUNT,2480547
# 689,post-transform DbPerfUtil.updateTableStatistics,53160
# 690,removeDuplicateEntity ACCOUNT,1413
# 691,runResolutionPhase1: DbPerfUtil.updateTableStatistics,4202
# 692,runResolution.ResolveCollectedAccounts.resolve,30377
# 693,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,28
# 694,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,190
# 695,runResolution.ResolveAccountOwners.resolve,4
# 696,runResolution.DbPerfUtil.updateTableStatistics,16
# 697,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,153
# 698,runResolution.ResolveCollectedPermissions.resolve,14
# 699,runResolution.ResolvePermissionsOwners.resolve,6
# 700,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,29458
# 701,TransitivePermissions.populateDistance1,7
# 702,TransitivePermissions.populateDirect,13
# 703,runResolutionPhase2: DbPerfUtil.updateTableStatistics,45
# 704,publish.MergeEntities.merge,1021
# 705,MergeEntities.mergeEntities (PERMISSION),103
# 706,MergeEntities.mergeEntities (ACCOUNT),846
# 707,publish.TagBuilder.buildSearchTag,687725
# 708,EntityTagBuilder: Building search tags for ACCOUNT,687675
# 709,EntityTagBuilder: Building search tags for PERMISSION,19
# 710,publish.ApplicationSummaries.populateApplicationSummary,17991
# 711,initApplicationSummary,27
# 712,updatePermissionCount,141
# 713,updateAccountCount,237
# 714,updateDanglingAccountCount,557
# 715,updateSharedAccountCount,794
# 716,addPermissionChanges,6469
# 717,updatePermissionChangeCount,258
# 718,addAccountChanges,9250
# 719,updateAccountChangeCount,46
# 720,publish.EntityChanges.addEntityChanges,18926
# 721, EntityChanges: EntityChanges.genAddedAppls ,46
# 722, EntityChanges: EntityChanges.genAddedPerms ,128
# 723, EntityChanges: EntityChanges.genAddedUsers ,16628
# 724, EntityChanges: EntityChanges.genAlteredPerms ,105
# 725, EntityChanges: EntityChanges.genAlteredUsers ,13
# 726, EntityChanges: EntityChanges.genRemovedPerms ,357
# 727, EntityChanges: EntityChanges.genRemovedUsers ,1572
# 728, EntityChanges: EntityChanges.genRemovedAppls ,49
# 729,publish.SnapshotDAO.updatepublishStateOnCollections ,30
# 730,publish.publishSnapshot,46852
# 731,publish.TagBuilder.cleanupAppSearchTagTables,8647
# 732,Publish.DbPerfUtil.updateTableStatistics,3161
# 733,Detect ALL Technical Roles,11
# 734,Detect ALL SoDs,8
# 735,DCS.collectData,501578
# 736,transformEntityType APPLICATION,120
# 737,post-transform DbPerfUtil.updateTableStatistics,28483
# 738,removeDuplicateEntity APPLICATION,2
# 739,transformEntityType ACCOUNT,38
# 740,post-transform DbPerfUtil.updateTableStatistics,15
# 741,removeDuplicateEntity ACCOUNT,86
# 742,transformEntityType PERMISSION,838
# 743,transformToPermission,796
# 744,post-transform DbPerfUtil.updateTableStatistics,932
# 745,removeDuplicateEntity PERMISSION,118
# 746,transformEntityType PERMISSION_TO_HOLDERS,20
# 747,post-transform DbPerfUtil.updateTableStatistics,13
# 748,removeDuplicateEntity PERMISSION_TO_HOLDERS,152
# 749,transformEntityType PERMISSIONS_FROM_HOLDER,17
# 750,post-transform DbPerfUtil.updateTableStatistics,14
# 751,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,3
# 752,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,14
# 753,post-transform DbPerfUtil.updateTableStatistics,14
# 754,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,1
# 755,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,13
# 756,post-transform DbPerfUtil.updateTableStatistics,13
# 757,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,2
# 758,runResolutionPhase1: DbPerfUtil.updateTableStatistics,5630
# 759,runResolution.IdentityManagerResolution.handleIDMPermissionExceptions,389
# 760,handleIDMPermissionExceptions.ResolveIDMAccounts.deleteProblemIDMAccounts,304
# 761,handleIDMPermissionExceptions.ResolveIDMPermissions.deleteProblemIDMPermissions,79
# 762,runResolution.IdentityManagerResolution.resolveAccountsAndPermissions,232
# 763,resolveAccountsAndPermissions.ResolveCollectedProvApplications.resolve ,7
# 764,resolveAccountsAndPermissions.ResolveIDMAccounts.resolveAccountToProvApp,56
# 765,resolveAccountsAndPermissions.ResolveIDMPermissions.resolvePermissionToProvApp,51
# 766,resolveAccountsAndPermissions.ResolveIDMPermissions.updateIDMBoundResourceParamName,11
# 767,resolveAccountsAndPermissions.ResolveIDMPermissions.resolveIDMPermissionFlags,19
# 768,runResolution.ResolveCollectedAccounts.resolve,12827
# 769,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,19
# 770,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,26
# 771,runResolution.ResolveAccountOwners.resolve,6
# 772,runResolution.DbPerfUtil.updateTableStatistics,18
# 773,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,112
# 774,runResolution.ResolveCollectedPermissions.resolve,14828
# 775,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,10622
# 776,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,11
# 777,resolvePermissionToHolder.ResolveUtil.createUserPermissions,903
# 778,createUserPermissions.createTPermissionUsers,453
# 779,createUserPermissions.updateTableStatistics#1,16
# 780,createUserPermissions.createVirtualAccounts,268
# 781,createUserPermissions.createSAccountUsers,16
# 782,createUserPermissions.updateTableStatistics#2,14
# 783,createUserPermissions.createVirtualAccountPermissions,14
# 784,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,3272
# 785,runResolution.ResolvePermissionsOwners.resolve,12778
# 786,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,8996
# 787,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,379
# 788,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,384
# 789,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,3364
# 790,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,217
# 791,TransitivePermissions.populateDistance1,35
# 792,TransitivePermissions.populateDirect,12
# 793,runResolution.AccountGrantPermission.resolve,9
# 794,runResolution.IdentityManagerResolution.resolveRolesToApplication,76
# 795,resolveRolesToApplication.ResolveIDMPermissions.resolveRolesToProvisoningApplication,70
# 796,runResolution.IdentityManagerResolution.resolveARResources,67
# 797,runResolutionPhase2: DbPerfUtil.updateTableStatistics,49
# 798,publish.MergeEntities.merge,349
# 799,MergeEntities.mergeEntities (PERMISSION),118
# 800,MergeEntities.mergeEntities (ACCOUNT),122
# 801,publish.TagBuilder.buildSearchTag,573
# 802,EntityTagBuilder: Building search tags for ACCOUNT,14
# 803,EntityTagBuilder: Building search tags for PERMISSION,500
# 804,publish.ApplicationSummaries.populateApplicationSummary,18927
# 805,initApplicationSummary,4
# 806,updatePermissionCount,70
# 807,updateAccountCount,225
# 808,updateDanglingAccountCount,481
# 809,updateSharedAccountCount,638
# 810,addPermissionChanges,8628
# 811,updatePermissionChangeCount,214
# 812,addAccountChanges,8589
# 813,updateAccountChangeCount,11
# 814,publish.EntityChanges.addEntityChanges,2818
# 815, EntityChanges: EntityChanges.genAddedAppls ,53
# 816, EntityChanges: EntityChanges.genAddedPerms ,116
# 817, EntityChanges: EntityChanges.genAddedUsers ,856
# 818, EntityChanges: EntityChanges.genAlteredPerms ,400
# 819, EntityChanges: EntityChanges.genAlteredUsers ,30
# 820, EntityChanges: EntityChanges.genRemovedPerms ,352
# 821, EntityChanges: EntityChanges.genRemovedUsers ,888
# 822, EntityChanges: EntityChanges.genRemovedAppls ,44
# 823,publish.SnapshotDAO.updatepublishStateOnCollections ,26
# 824,publish.publishSnapshot,1125
# 825,publish.TagBuilder.cleanupAppSearchTagTables,734
# 826,Publish.DbPerfUtil.updateTableStatistics,155
# 827,Detect ALL Technical Roles,6
# 828,Detect ALL SoDs,5
# 829,DCS.collectData,130768
# 830,transformEntityType PERMISSION,2503128
# 831,transformToPermission,661761
# 832,transformToPermission,663075
# 833,transformToPermission,664806
# 834,transformToPermission,499590
# 835,post-transform DbPerfUtil.updateTableStatistics,74837
# 836,removeDuplicateEntity PERMISSION,396
# 837,transformEntityType PERMISSION_TO_HOLDERS,39
# 838,post-transform DbPerfUtil.updateTableStatistics,12
# 839,removeDuplicateEntity PERMISSION_TO_HOLDERS,24652
# 840,transformEntityType PERMISSIONS_FROM_HOLDER,33
# 841,post-transform DbPerfUtil.updateTableStatistics,12
# 842,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,13041
# 843,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,34
# 844,post-transform DbPerfUtil.updateTableStatistics,10
# 845,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,2
# 846,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,29
# 847,post-transform DbPerfUtil.updateTableStatistics,10
# 848,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,2
# 849,runResolutionPhase1: DbPerfUtil.updateTableStatistics,54
# 850,runResolution.ResolveCollectedAccounts.resolve,52
# 851,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,4910
# 852,runResolution.ResolveAccountOwners.resolve,9
# 853,runResolution.DbPerfUtil.updateTableStatistics,67
# 854,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,7281
# 855,runResolution.ResolveCollectedPermissions.resolve,1475296
# 856,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,223291
# 857,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,3108
# 858,resolvePermissionToHolder.ResolveUtil.createUserPermissions,1246023
# 859,createUserPermissions.createTPermissionUsers,103338
# 860,createUserPermissions.updateTableStatistics#1,7194
# 861,createUserPermissions.createVirtualAccounts,100993
# 862,createUserPermissions.createSAccountUsers,18156
# 863,createUserPermissions.updateTableStatistics#2,14
# 864,createUserPermissions.createVirtualAccountPermissions,259678
# 865,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,5902
# 866,runResolution.ResolvePermissionsOwners.resolve,166771
# 867,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,162593
# 868,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,7304
# 869,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,347
# 870,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,3759
# 871,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,17135
# 872,TransitivePermissions.populateDistance1,39
# 873,TransitivePermissions.populateDirect,12
# 874,runResolutionPhase2: DbPerfUtil.updateTableStatistics,112
# 875,publish.MergeEntities.merge,1480
# 876,MergeEntities.mergeEntities (PERMISSION),133
# 877,MergeEntities.mergeEntities (ACCOUNT),1310
# 878,publish.TagBuilder.buildSearchTag,59697
# 879,EntityTagBuilder: Building search tags for ACCOUNT,219
# 880,EntityTagBuilder: Building search tags for PERMISSION,59443
# 881,publish.ApplicationSummaries.populateApplicationSummary,25162
# 882,initApplicationSummary,28
# 883,updatePermissionCount,117
# 884,updateAccountCount,248
# 885,updateDanglingAccountCount,551
# 886,updateSharedAccountCount,704
# 887,addPermissionChanges,8874
# 888,updatePermissionChangeCount,217
# 889,addAccountChanges,14280
# 890,updateAccountChangeCount,15
# 891,publish.EntityChanges.addEntityChanges,3614
# 892, EntityChanges: EntityChanges.genAddedAppls ,94
# 893, EntityChanges: EntityChanges.genAddedPerms ,190
# 894, EntityChanges: EntityChanges.genAddedUsers ,1496
# 895, EntityChanges: EntityChanges.genAlteredPerms ,128
# 896, EntityChanges: EntityChanges.genAlteredUsers ,11
# 897, EntityChanges: EntityChanges.genRemovedPerms ,234
# 898, EntityChanges: EntityChanges.genRemovedUsers ,1369
# 899, EntityChanges: EntityChanges.genRemovedAppls ,42
# 900,publish.SnapshotDAO.updatepublishStateOnCollections ,6
# 901,publish.publishSnapshot,247720
# 902,publish.TagBuilder.cleanupAppSearchTagTables,4688
# 903,Publish.DbPerfUtil.updateTableStatistics,8580
# 904,Detect ALL Technical Roles,6
# 905,Detect ALL SoDs,20
# 906,TrivialUserGeneration.createSUsersWithoutExistingUniqueId,399
# 907,NonTrivialUserGeneration.clearJoinAttributeTables,101
# 908,NonTrivialUserGeneration.populateSUserJoinAttributes,211990
# 909,NonTrivialUserGeneration.populateCUserJoinAttributes,82011
# 910,NonTrivialUserGeneration.findCUserUniqueUserIds,11972
# 911,NonTrivialUserGeneration.updateSUsersFromJoinedCUsers.Query,792
# 912,NonTrivialUserGeneration.updateSUsersFromJoinedCUsers.Process,2
# 913,NonTrivialUserGeneration.flagUnmatchedCUsersWithMatchingUniqueId.Query,2241
# 914,NonTrivialUserGeneration.flagUnmatchedCUsersWithMatchingUniqueId.Process,2
# 915,NonTrivialUserGeneration.createSUsersFromUnjoinedCUsers.Query,1424
# 916,NonTrivialUserGeneration.createSUsersFromUnjoinedCUsers.Process,16791292
# 917,before:resolveNullUniqueUserIds.DbPerfUtil.updateTableStatistics,5265
# 918,resolveNullUniqueUserIds.Query,14
# 919,resolveNullUniqueUserIds.Process,1
# 920,Unification-PhaseI.DbPerfUtil.updateTableStatistics,9
# 921,analyzeUnification,1273
# 922,SnapshotDAO.realizeUnificationSnapshot,187762
# 923,UserRefResolution.resolveUserReferences,87358
# 924,resolveUserReferences.populateSUserJoinAttributes,10503
# 925,resolveUserReferences.DbPerfUtil.updateTableStatistics,252
# 926,resolveUserReferences.removeAmbiguousSUserJoinAttributes,250
# 927,resolveUserReferences.resolveSupervisorsDirectly,14761
# 928,resolveUserReferences.resolveOwners,342
# 929,resolveUserReferences.UserDerivedAttrResolution.resolve,61176
# 930,TransitiveSubgroups.generate,175
# 931,TransitiveSubgroups.generate (distance=1),153
# 932,Publication.publish,1874072
# 933,publish.MergeEntities.merge,771
# 934,MergeEntities.mergeEntities (USER),587
# 935,MergeEntities:UserDerivedAttrResolution.resolve,163
# 936,MergeEntities.mergeIDMUserInfoFromPriorVersion,3
# 937,publish.PermissionsOwnerUnlinker.unlinkDeletedSusersFromPermissionOwners,155
# 938,publish.AccountsOwnerUnlinker.unlinkDeletedSusersFromAccountOwners,168
# 939,publish.AccountRelationTypeUtil.populateAccountRelationTypes,40085
# 940,publish.TagBuilder.buildSearchTag,452947
# 941,EntityTagBuilder: Building search tags for USER,356505
# 942,EntityTagBuilder: Building search tags for GROUP,96340
# 943,publish.ApplicationSummaries.populateApplicationSummary,16366
# 944,initApplicationSummary,111
# 945,updatePermissionCount,61
# 946,updateAccountCount,288
# 947,updateDanglingAccountCount,494
# 948,updateSharedAccountCount,656
# 949,addPermissionChanges,4988
# 950,updatePermissionChangeCount,243
# 951,addAccountChanges,9352
# 952,updateAccountChangeCount,117
# 953,publish.EntityChanges.addEntityChanges,1261738
# 954, EntityChanges: EntityChanges.genAddedAppls ,56
# 955, EntityChanges: EntityChanges.genAddedPerms ,184
# 956, EntityChanges: EntityChanges.genAddedUsers ,1479
# 957, EntityChanges: EntityChanges.genAlteredPerms ,104
# 958, EntityChanges: EntityChanges.genAlteredUsers ,1257463
# 959, EntityChanges: EntityChanges.genRemovedPerms ,484
# 960, EntityChanges: EntityChanges.genRemovedUsers ,1865
# 961, EntityChanges: EntityChanges.genRemovedAppls ,50
# 962,publish.SnapshotDAO.updatepublishStateOnCollections ,4
# 963,publish.publishSnapshot,90926
# 964,publish.TagBuilder.cleanupIdentitySearchTagTables,10807
# 965,Publish.DbPerfUtil.updateTableStatistics,12
# 966,Detect ALL Technical Roles,19
# 967,Detect ALL SoDs,8
# 968,DCS.collectData,436579
# 969,transformEntityType APPLICATION,30
# 970,post-transform DbPerfUtil.updateTableStatistics,46
# 971,removeDuplicateEntity APPLICATION,3
# 972,transformEntityType ACCOUNT,15
# 973,post-transform DbPerfUtil.updateTableStatistics,18
# 974,removeDuplicateEntity ACCOUNT,138
# 975,transformEntityType PERMISSION,310
# 976,transformToPermission,277
# 977,post-transform DbPerfUtil.updateTableStatistics,13
# 978,removeDuplicateEntity PERMISSION,123
# 979,transformEntityType PERMISSION_TO_HOLDERS,13
# 980,post-transform DbPerfUtil.updateTableStatistics,10
# 981,removeDuplicateEntity PERMISSION_TO_HOLDERS,18656
# 982,transformEntityType PERMISSIONS_FROM_HOLDER,15
# 983,post-transform DbPerfUtil.updateTableStatistics,31
# 984,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,1164
# 985,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,17
# 986,post-transform DbPerfUtil.updateTableStatistics,80
# 987,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,2
# 988,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,12
# 989,post-transform DbPerfUtil.updateTableStatistics,9
# 990,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,2
# 991,runResolutionPhase1: DbPerfUtil.updateTableStatistics,20
# 992,runResolution.IdentityManagerResolution.handleIDMPermissionExceptions,598
# 993,handleIDMPermissionExceptions.ResolveIDMAccounts.deleteProblemIDMAccounts,468
# 994,handleIDMPermissionExceptions.ResolveIDMPermissions.deleteProblemIDMPermissions,124
# 995,runResolution.IdentityManagerResolution.resolveAccountsAndPermissions,2084
# 996,resolveAccountsAndPermissions.ResolveCollectedProvApplications.resolve ,3
# 997,resolveAccountsAndPermissions.ResolveIDMAccounts.resolveAccountToProvApp,281
# 998,resolveAccountsAndPermissions.ResolveIDMPermissions.resolvePermissionToProvApp,157
# 999,resolveAccountsAndPermissions.ResolveIDMPermissions.updateIDMBoundResourceParamName,12
# 1000,resolveAccountsAndPermissions.ResolveIDMPermissions.resolveIDMPermissionFlags,1612
# 1001,runResolution.ResolveCollectedAccounts.resolve,13169
# 1002,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,12
# 1003,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,23
# 1004,runResolution.ResolveAccountOwners.resolve,28
# 1005,runResolution.DbPerfUtil.updateTableStatistics,20
# 1006,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,211
# 1007,runResolution.ResolveCollectedPermissions.resolve,14344
# 1008,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,9957
# 1009,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,15
# 1010,resolvePermissionToHolder.ResolveUtil.createUserPermissions,866
# 1011,createUserPermissions.createTPermissionUsers,466
# 1012,createUserPermissions.updateTableStatistics#1,10
# 1013,createUserPermissions.createVirtualAccounts,185
# 1014,createUserPermissions.createSAccountUsers,97
# 1015,createUserPermissions.updateTableStatistics#2,15
# 1016,createUserPermissions.createVirtualAccountPermissions,13
# 1017,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,3483
# 1018,runResolution.ResolvePermissionsOwners.resolve,15385
# 1019,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,11757
# 1020,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,240
# 1021,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,425
# 1022,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,3185
# 1023,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,237
# 1024,TransitivePermissions.populateDistance1,36
# 1025,TransitivePermissions.populateDirect,5
# 1026,runResolution.AccountGrantPermission.resolve,13
# 1027,runResolution.IdentityManagerResolution.resolveRolesToApplication,46
# 1028,resolveRolesToApplication.ResolveIDMPermissions.resolveRolesToProvisoningApplication,39
# 1029,runResolution.IdentityManagerResolution.resolveARResources,101
# 1030,runResolutionPhase2: DbPerfUtil.updateTableStatistics,22
# 1031,publish.MergeEntities.merge,81
# 1032,MergeEntities.mergeEntities (PERMISSION),39
# 1033,MergeEntities.mergeEntities (ACCOUNT),30
# 1034,publish.TagBuilder.buildSearchTag,389
# 1035,EntityTagBuilder: Building search tags for ACCOUNT,9
# 1036,EntityTagBuilder: Building search tags for PERMISSION,362
# 1037,publish.ApplicationSummaries.populateApplicationSummary,16845
# 1038,initApplicationSummary,39
# 1039,updatePermissionCount,29
# 1040,updateAccountCount,209
# 1041,updateDanglingAccountCount,445
# 1042,updateSharedAccountCount,563
# 1043,addPermissionChanges,6331
# 1044,updatePermissionChangeCount,249
# 1045,addAccountChanges,8886
# 1046,updateAccountChangeCount,42
# 1047,publish.EntityChanges.addEntityChanges,3148
# 1048, EntityChanges: EntityChanges.genAddedAppls ,4
# 1049, EntityChanges: EntityChanges.genAddedPerms ,111
# 1050, EntityChanges: EntityChanges.genAddedUsers ,1477
# 1051, EntityChanges: EntityChanges.genAlteredPerms ,9
# 1052, EntityChanges: EntityChanges.genAlteredUsers ,4
# 1053, EntityChanges: EntityChanges.genRemovedPerms ,137
# 1054, EntityChanges: EntityChanges.genRemovedUsers ,1381
# 1055, EntityChanges: EntityChanges.genRemovedAppls ,5
# 1056,publish.SnapshotDAO.updatepublishStateOnCollections ,4
# 1057,publish.publishSnapshot,3766
# 1058,publish.TagBuilder.cleanupAppSearchTagTables,1181
# 1059,Publish.DbPerfUtil.updateTableStatistics,17
# 1060,Detect ALL Technical Roles,7
# 1061,Detect ALL SoDs,8
# 1062,DCS.collectData,135323
# 1063,transformEntityType PERMISSION,1861479
# 1064,transformToPermission,491829
# 1065,transformToPermission,486966
# 1066,transformToPermission,491826
# 1067,transformToPermission,379704
# 1068,post-transform DbPerfUtil.updateTableStatistics,31087
# 1069,removeDuplicateEntity PERMISSION,731
# 1070,transformEntityType PERMISSION_TO_HOLDERS,375
# 1071,post-transform DbPerfUtil.updateTableStatistics,5150
# 1072,removeDuplicateEntity PERMISSION_TO_HOLDERS,20769
# 1073,transformEntityType PERMISSIONS_FROM_HOLDER,49
# 1074,post-transform DbPerfUtil.updateTableStatistics,10
# 1075,removeDuplicateEntity PERMISSIONS_FROM_HOLDER,14471
# 1076,transformEntityType PERMISSION_HIERARCHY_TO_CHILD,34
# 1077,post-transform DbPerfUtil.updateTableStatistics,14
# 1078,removeDuplicateEntity PERMISSION_HIERARCHY_TO_CHILD,3
# 1079,transformEntityType PERMISSION_HIERARCHY_TO_PARENT,33
# 1080,post-transform DbPerfUtil.updateTableStatistics,11
# 1081,removeDuplicateEntity PERMISSION_HIERARCHY_TO_PARENT,2
# 1082,runResolutionPhase1: DbPerfUtil.updateTableStatistics,10
# 1083,runResolution.ResolveCollectedAccounts.resolve,5
# 1084,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,5490
# 1085,runResolution.ResolveAccountOwners.resolve,7
# 1086,runResolution.DbPerfUtil.updateTableStatistics,16
# 1087,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,4290
# 1088,runResolution.ResolveCollectedPermissions.resolve,750939
# 1089,resolvePermissionToHolder.ResolveUtil.createUserAttributeJoins,9664
# 1090,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,22
# 1091,resolvePermissionToHolder.ResolveUtil.createUserPermissions,732488
# 1092,createUserPermissions.createTPermissionUsers,101959
# 1093,createUserPermissions.updateTableStatistics#1,16
# 1094,createUserPermissions.createVirtualAccounts,87627
# 1095,createUserPermissions.createSAccountUsers,19039
# 1096,createUserPermissions.updateTableStatistics#2,14
# 1097,createUserPermissions.createVirtualAccountPermissions,265965
# 1098,resolvePermissionToHolder.ResolveUtil.clearUserAttributeJoins,8692
# 1099,runResolution.ResolvePermissionsOwners.resolve,33342
# 1100,resolvePermissionCollectedOwnersToOwners.ResolveUtil.createUserAttributeJoins,25599
# 1101,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,456
# 1102,resolvePermissionCollectedOwnersToOwners.updatePermissionUserOwners,503
# 1103,resolvePermissionCollectedOwnersToOwners.ResolveUtil.clearUserAttributeJoins,7219
# 1104,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,9413
# 1105,TransitivePermissions.populateDistance1,38
# 1106,TransitivePermissions.populateDirect,4
# 1107,runResolutionPhase2: DbPerfUtil.updateTableStatistics,87
# 1108,publish.MergeEntities.merge,387
# 1109,MergeEntities.mergeEntities (PERMISSION),54
# 1110,MergeEntities.mergeEntities (ACCOUNT),325
# 1111,publish.TagBuilder.buildSearchTag,54038
# 1112,EntityTagBuilder: Building search tags for ACCOUNT,256
# 1113,EntityTagBuilder: Building search tags for PERMISSION,53765
# 1114,publish.ApplicationSummaries.populateApplicationSummary,15042
# 1115,initApplicationSummary,36
# 1116,updatePermissionCount,65
# 1117,updateAccountCount,259
# 1118,updateDanglingAccountCount,507
# 1119,updateSharedAccountCount,614
# 1120,addPermissionChanges,4160
# 1121,updatePermissionChangeCount,213
# 1122,addAccountChanges,9086
# 1123,updateAccountChangeCount,43
# 1124,publish.EntityChanges.addEntityChanges,2281
# 1125, EntityChanges: EntityChanges.genAddedAppls ,44
# 1126, EntityChanges: EntityChanges.genAddedPerms ,143
# 1127, EntityChanges: EntityChanges.genAddedUsers ,827
# 1128, EntityChanges: EntityChanges.genAlteredPerms ,142
# 1129, EntityChanges: EntityChanges.genAlteredUsers ,4
# 1130, EntityChanges: EntityChanges.genRemovedPerms ,218
# 1131, EntityChanges: EntityChanges.genRemovedUsers ,834
# 1132, EntityChanges: EntityChanges.genRemovedAppls ,47
# 1133,publish.SnapshotDAO.updatepublishStateOnCollections ,29
# 1134,publish.publishSnapshot,277063
# 1135,publish.TagBuilder.cleanupAppSearchTagTables,2430
# 1136,Publish.DbPerfUtil.updateTableStatistics,132
# 1137,Detect ALL Technical Roles,72
# 1138,Detect ALL SoDs,8
# 1139,DCS.collectData,280157
# 1140,transformEntityType ACCOUNT,1103796
# 1141,post-transform DbPerfUtil.updateTableStatistics,2311
# 1142,removeDuplicateEntity ACCOUNT,10797
# 1143,runResolutionPhase1: DbPerfUtil.updateTableStatistics,18
# 1144,runResolution.ResolveCollectedAccounts.resolve,30864
# 1145,createUserAttributeJoins.DbPerfUtil.updateTableStatistics,11
# 1146,runResolution.ResolveCollectedAccount.totalAccountsInSnapshot,184
# 1147,runResolution.ResolveAccountOwners.resolve,7
# 1148,runResolution.DbPerfUtil.updateTableStatistics,23
# 1149,runResolution.ResolveCollectedPermissions.totalPermissionsHoldersInSnapshot,44
# 1150,runResolution.ResolveCollectedPermissions.resolve,9
# 1151,runResolution.ResolvePermissionsOwners.resolve,8
# 1152,runResolution.AccountRelationTypeUtil.populateAccountRelationTypes,27262
# 1153,TransitivePermissions.populateDistance1,3
# 1154,TransitivePermissions.populateDirect,4
# 1155,runResolutionPhase2: DbPerfUtil.updateTableStatistics,17
# 1156,publish.MergeEntities.merge,323
# 1157,MergeEntities.mergeEntities (PERMISSION),34
# 1158,MergeEntities.mergeEntities (ACCOUNT),279
# 1159,publish.TagBuilder.buildSearchTag,601307
# 1160,EntityTagBuilder: Building search tags for ACCOUNT,601281
# 1161,EntityTagBuilder: Building search tags for PERMISSION,9
# 1162,publish.ApplicationSummaries.populateApplicationSummary,21197
# 1163,initApplicationSummary,3
# 1164,updatePermissionCount,56
# 1165,updateAccountCount,291
# 1166,updateDanglingAccountCount,557
# 1167,updateSharedAccountCount,753
# 1168,addPermissionChanges,8300
# 1169,updatePermissionChangeCount,293
# 1170,addAccountChanges,10885
# 1171,updateAccountChangeCount,9
# 1172,publish.EntityChanges.addEntityChanges,2291
# 1173, EntityChanges: EntityChanges.genAddedAppls ,44
# 1174, EntityChanges: EntityChanges.genAddedPerms ,185
# 1175, EntityChanges: EntityChanges.genAddedUsers ,811
# 1176, EntityChanges: EntityChanges.genAlteredPerms ,130
# 1177, EntityChanges: EntityChanges.genAlteredUsers ,9
# 1178, EntityChanges: EntityChanges.genRemovedPerms ,228
# 1179, EntityChanges: EntityChanges.genRemovedUsers ,798
# 1180, EntityChanges: EntityChanges.genRemovedAppls ,41
# 1181,publish.SnapshotDAO.updatepublishStateOnCollections ,4
# 1182,publish.publishSnapshot,40776
# 1183,publish.TagBuilder.cleanupAppSearchTagTables,10219
# 1184,Publish.DbPerfUtil.updateTableStatistics,120
# 1185,Detect ALL Technical Roles,8
# 1186,Detect ALL SoDs,7
# 1187,StartReview (Everyone and the kitchen sink): Generate Items,43517206
# 1188,StartReview (Everyone and the kitchen sink): Start workflow for notifications,225
# 1189,StartReview (Everyone and the kitchen sink): Generate Runtime roles,6845
# 1190,StartReview (Everyone and the kitchen sink): Calculate Certification Policies,49
# 1191,StartReview (Everyone and the kitchen sink): Update Statistics.  You can stop this calculation by setting the global config setting iac.update.stats.review.disabled to true.,4748
# 1192,synchronizeWithDataProductionTasks : 172,8
# 1193,validate autocuration upload process -id : 172,15
# 1195,execute Account curation ,562
# 1196,execute Account curation .executeCuration.uploadCuration,49
# 1197,uploadCuration: getAccounts(53),36
# 1198,execute Account curation .executeCuration.publish,502
# 1199,updateCuratedAccounts,182
# 1200,query for merged accounts,11
# 1201,Build search tags,302
# 1202, Building search tag table for ACCOUNT,136
# 1203,updating account custodians,4
# 1204,Completing state update for autocuration process - id : 172,15
# 1205,synchronizeWithDataProductionTasks : 173,2
# 1206,validate autocuration upload process -id : 173,9
# 1208,execute Account curation ,314
# 1209,execute Account curation .executeCuration.uploadCuration,104
# 1210,uploadCuration: getAccounts(54),99
# 1211,execute Account curation .executeCuration.publish,202
# 1212,updateCuratedAccounts,14
# 1213,query for merged accounts,8
# 1214,Build search tags,176
# 1215, Building search tag table for ACCOUNT,120
# 1216,updating account custodians,2
# 1217,Completing state update for autocuration process - id : 173,10

# %%
perflog_df_narrow['ELAPSED'] = perflog_df_narrow['ELAPSED'].astype('int')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
perflog_df_narrow.dtypes
# Out:
# MONITOR    object
# ELAPSED     int64
# dtype: object
